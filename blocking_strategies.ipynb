# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
# Step 1: Load the data
df = pd.read_csv('dblp_names.csv', on_bad_lines='warn')
print(f"Initial records: {len(df)}")
df.head(10)
# Out:
# Initial records: 45156
# C:\Users\cheth\AppData\Local\Temp\ipykernel_2388\2457895722.py:2: ParserWarning: Skipping line 164: expected 2 fields, saw 3
# Skipping line 281: expected 2 fields, saw 3
# Skipping line 512: expected 2 fields, saw 3
# Skipping line 839: expected 2 fields, saw 3
# Skipping line 854: expected 2 fields, saw 3
# Skipping line 1997: expected 2 fields, saw 3
# Skipping line 2631: expected 2 fields, saw 3
# Skipping line 2642: expected 2 fields, saw 3
# Skipping line 2656: expected 2 fields, saw 3
# Skipping line 2658: expected 2 fields, saw 3
# Skipping line 2659: expected 2 fields, saw 3
# Skipping line 6310: expected 2 fields, saw 3
# Skipping line 10753: expected 2 fields, saw 3
# Skipping line 11044: expected 2 fields, saw 3
# Skipping line 18510: expected 2 fields, saw 3
# Skipping line 31242: expected 2 fields, saw 3
# Skipping line 41259: expected 2 fields, saw 3
# Skipping line 41633: expected 2 fields, saw 3
# Skipping line 43561: expected 2 fields, saw 3
# Skipping line 43569: expected 2 fields, saw 3
#
#   df = pd.read_csv('dblp_names.csv', on_bad_lines='warn')
#                # OLD_NAME                NEW_NAME
# 0       Bamshad Mobasherm        Bamshad Mobasher
# 1  Carole Delporte-Gellet  Carole Delporte-Gallet
# 2     Ronald Presott Loui    Ronald Prescott Loui
# 3              Eve Riskin           Eve A. Riskin
# 4       Doouglas W. Clark        Douglas W. Clark
# 5         P. R. S. Visser     Pepijn R. S. Visser
# 6           Pepijn Visser     Pepijn R. S. Visser
# 7        A. Pietracaprina    Andrea Pietracaprina
# 8           M. R. Swanson         Mark R. Swanson
# 9   Matilde Celma-Giménez           Matilde Celma

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45156 entries, 0 to 45155
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   # OLD_NAME  45156 non-null  object
#  1    NEW_NAME   45156 non-null  object
# dtypes: object(2)
# memory usage: 705.7+ KB

# %%
all_names = set(df['# OLD_NAME']) | set(df[' NEW_NAME'])
all_names
# Out:
# {'Jean-Pierre Dautricourt',
#  'W. L. F. Degen',
#  'A. Guénoche',
#  'Sung-Eon Cho',
#  'Tom Meitzler',
#  'Tomasz Luczak',
#  'Pavel Tichý',
#  'Xuegang Chen',
#  'Habib Mehrez',
#  'Louis C. Quintas',
#  'Manuel J. Maña-López',
#  'W. Hesse',
#  'Neal R. Harvey',
#  'Won-Gyum Kim',
#  'Baba Vemuri',
#  'Susan McRoy',
#  'Martha Crosby',
#  'György Vaszil',
#  'Debra A. Hope',
#  'Saied Hosseini Khayat',
#  'Gustovo Alonso',
#  'Jonathan F. Bard',
#  'Sverre Holm',
#  'Chong-You Zheng',
#  'Jürg Kohlhas',
#  'Umesh Vazirani',
#  'Bob Gerber',
#  'Krishan K. Sanbani',
#  'Zhang Longbo',
#  'Tarantilis D. Tarantilis',
#  'Mark G. Slack',
#  'Lawrence B. Wolff',
#  'Oleg T. Balovnev',
#  'Paolo Bernardi',
#  'Siand Wun Song',
#  'Ugo De Carlini',
#  'Samee Ullah Khan',
#  'E. Okamoto',
#  'Saleh Alshebeili',
#  'C. Higgins',
#  'Ozalp Babaoglu',
#  'Trent Jaegar',
#  'Tamás Horváth',
#  'Arye Nehorai',
#  'Keno Albrecht',
#  'Chunkai Zhang',
#  'Alexander E. Emanuel',
#  'Wing-lok Yeung',
#  'Laura Mota-Herranz',
#  'Jane-Jing Liang',
#  'Axel T. Brünger',
#  'M. Mazo',
#  'Matthew R. Rudary',
#  'Giacomo Piscitelli',
#  'Thomas Schlögl',
#  'Petru Eles',
#  'D. Küpper',
#  'William M. Wels',
#  'F. Félix Lara Martin',
#  'Tomokatsu Hori',
#  'P. C. Young',
#  'Linzhong Liu',
#  'Elie Bienenstock',
#  'Tae Young Choi',
#  'J. Schanda',
#  'Hadjidemetriou Hadjidemetriou',
#  'Massimo Violante',
#  'Jinfieng Yang',
#  'G. Geiger',
#  'Hans Roubos',
#  'Ashraf Elnagar',
#  'Antônio Otávio Fernandes',
#  'Mou Xuanqin',
#  'Dong Ku Kim',
#  'D. W. Conrath',
#  'Peter Lawrence',
#  'Abdolreza A. Moghadam',
#  'M. Chover',
#  'C. Godart',
#  'G. Tzimas',
#  'B. A. Barsky',
#  'William S. Hlavacek',
#  'Q. Peng',
#  'Ayush Bandari',
#  'Barbara Zitová',
#  'A. Naumenko',
#  'François Rhéaume',
#  'Lawrene Snyder',
#  'Kurt Vanlehn',
#  'Yoshiaki Takata',
#  'C. Stiller',
#  'Frank Dehne',
#  'Ren Shouju',
#  'Dick Tsur',
#  'Cheng Lin Liu',
#  'Chun-yan Bai',
#  'Shou-Hsuan Stephen Huang',
#  'Amaury Habrand',
#  'Thomas Wölfl',
#  'Atilla Gürsoy',
#  'Jimmy H. P. Chim',
#  'Chengdong Shen',
#  'I. V. Bajic',
#  'Julie Stilson',
#  'H. Joseph Y. Halpern',
#  'Leandro Chaves Rego',
#  'Kuiyu Li',
#  'Pui-On Au',
#  'Marta Sabou',
#  'Sumanta Guha',
#  'Carlos Lucena',
#  'Francesco Archetti',
#  'Chrisrtian Bunse',
#  'Iakes Goenaga',
#  'Erik A. Hendriks',
#  'Y. S. Yeh',
#  'Deng Pan',
#  'Sebastián A. Ríos',
#  'Karan Verma',
#  'Marwan Awad',
#  'Mihran Tuceryan',
#  'Juan Cedano',
#  'R. Grob',
#  'Shenwei Zhang',
#  'S. Pasupathy',
#  'Eric King-wah Chu',
#  'Mohammed Mostefa Mesmoudi',
#  'Yunmei Chen',
#  'Bradford W. Miller',
#  'Luís M. M. Custódio',
#  'Shinn-Jang Ho',
#  'Eenjan Hwang',
#  'Reyer Zwiggelaar',
#  'John H. Reif',
#  'Xiaojian He',
#  'N. Swamy',
#  'Adam L. Berger',
#  'F. Mignosi',
#  'Alessandro Bosco',
#  'Gautam Das',
#  'Paul Erdös',
#  'Igor Hawryszkiewycz',
#  'P. K. Ghosh',
#  'Ooussama Khatib',
#  'Itván Nemeti',
#  'Inmaculada Gallego',
#  'Julián Ramos Cozar',
#  'Francisco Triguero Ruiz',
#  'S. Yalamanchili',
#  'Joseph Evans',
#  'Jae-Kyeong Kim',
#  'Luuk Van Waes',
#  'H. Hegering',
#  'Ren Qun',
#  'C. Capjack',
#  'Simon Baatz',
#  'Leslie Cheung',
#  'QingMao Hu',
#  'Aliakbar Montazer-Haghighi',
#  'D. Manini',
#  'Gordon Rose',
#  'Melkemi Mahmoud',
#  'Hojjat Adeli',
#  'Manuel Nunez',
#  'Rob C. Knauerhase',
#  'Alexandre C. B Delbem',
#  'Lluís Padró',
#  'Thad A Polk',
#  'María Cristina Riff Rojas',
#  'A. Zell',
#  'Jean-Pierre Schoellkopf',
#  'Paul J. Wagner',
#  'Josep Maria Porta',
#  'Nikolaos G. Bourbaki',
#  'I. H. Sorensen',
#  'Jean-Paul Barthés',
#  'Kishore Sakharkar',
#  'Blanca Rodriguez',
#  'P. H. Algoet',
#  'Issam A. R. Moghrabi',
#  'Narciso N. García',
#  'Babak Akhgar',
#  'B. Haut',
#  'Wolfgang Stürzlinger',
#  'Stephen I. Long',
#  'A. Coumar',
#  'T. I. Wang',
#  'Óscar Pedreira Fernández',
#  'Piotr Hoffman',
#  'Choon-Han Youn',
#  'M. M. Van Hulle',
#  'Mingmin Zhang',
#  'David Robertson',
#  'Miguel Goulão',
#  'David J. H. Brock',
#  'David W. Wall',
#  'Dragan Marusic',
#  'Ashfaq Khokhar',
#  'S. Mann',
#  'Mandaly Grems',
#  'K. Ramachandran',
#  'Barbara Becker',
#  'David Chih-Wei Chang',
#  'Paul Bailes',
#  'Donatella Marini',
#  'Markus W. Büchler',
#  'G. Enderle',
#  'Pauline Mata',
#  'Ganesh N. Ramaswamy',
#  'M. de los Angeles Martín',
#  'Rebecca Richards-Kortum',
#  'Wang Pei Zhuang',
#  'Hans-Hellmut Nagel',
#  'D. Muthiaye',
#  'Philpe A. Janson',
#  'Srikantan Nagarajan',
#  'V. C. V. de Paiva',
#  'Aliakbar Montazer Haghighi',
#  'M. Awad',
#  'S. A. Aksoyoglu',
#  'Eric R. Hughes',
#  'William Foster',
#  'Volker Haarsler',
#  'Soren Moch',
#  "Shun'ichi Kaneko",
#  'Ewal Speckenmeyer',
#  'Jim W. Forgie',
#  'Jose M. Pérez',
#  'Nicholas J. Cavenagh',
#  'A. Smyk',
#  'Ruhul Sarker',
#  'Juan P. Palacios',
#  'C. Rosenberger',
#  'Kwang-Ting Tim Cheng',
#  'A. Grigg',
#  'Jérome Fournier',
#  'Roslin V. Hauck',
#  'A. Buller',
#  'Lukas Hejtmanek',
#  'James H. Anderson',
#  'DongWoo Lee',
#  'Caroline Barrihre',
#  'DavidE. Culler',
#  'Rffaele Cappelli',
#  'Juan José Rodriguez',
#  'Alex Biryukov',
#  'Dionisios N. Pnevmatikatos',
#  'C. Duriez',
#  'Pasi Tyrvainen',
#  'Jens Clausen',
#  'Leonid Peshkin',
#  'Hans-Jurgen Bandelt',
#  'Zakaria Maamar',
#  'I. de Miguel',
#  'H. Haverinen',
#  'André van der Hoek',
#  'Aimo A. Törn',
#  'Kailasam Visvanathan Iyer',
#  'Aleaandro Finamore',
#  'Guoliang Zheng',
#  'Paolo Campadelli',
#  'D. I. Fotiadis',
#  'Burkhard Molzan',
#  'Thomas O. Binford',
#  'Manny Raynez',
#  'Robert Cedergren',
#  'Sun Weiwei',
#  'Kristinn R. Thorisson',
#  'Elder Moreira Hemerly',
#  'C. W. Chu',
#  'Bob Balzer',
#  'Juan Carlos Ruiz',
#  'Edmond C. Loyot',
#  'F. R. K. Chung',
#  'Dowan Kwon',
#  'PhuongAn Dam',
#  'M. Rönnqvist',
#  'George G. Grinstein',
#  'Øystein Sæbø',
#  'Daniela Pucci de Farias',
#  'E. Abdel-Raheem',
#  'Nils T. Siebel',
#  'Lilian Noronha Nassif',
#  'Ulrich Lan',
#  'D. Song',
#  'Pramode K. Verma',
#  'Claus Braband',
#  'S. P. Ninomija',
#  'Robert F. Stärk',
#  'Simon Keates',
#  'G. Campion',
#  'Mihail Nedjalkov',
#  'André M. DeHon',
#  'Hisashi Miyamori',
#  'Shauchi Ong',
#  'Rodion Podorozhny',
#  'Hirozurni Yamaguchi',
#  'Chan See',
#  'Jianlai Zhou',
#  'George Karakostas',
#  'V. Srinivasmurthy',
#  'David Kravitz',
#  'Ascensión Gallardo-Antolin',
#  'Ron van Duin',
#  'R. Kent Dybig',
#  'J. Ortega',
#  'Luis Carlos Molina',
#  'Tomi Männistö',
#  'Jochen Kuester',
#  'Roberto Saletti',
#  'Steve Kleiman',
#  'Giulia Galbiati',
#  'Dencho Batanov',
#  'Ryan S. Baker',
#  'B. Lang',
#  'Mourad Kara',
#  'Ron J. Balsys',
#  'Matteo Rossi',
#  'Maria Grazia Fugini',
#  'Emre Gündüzhan',
#  'Daniel Tomasevic',
#  'Antonioa Izquierdo',
#  'Sangchul Han',
#  'Shin-Dug Kim',
#  'R. A. Earnshaw',
#  'Dumitru Mihai Ionescu',
#  'H. G. Barrow',
#  'Thilo Götz',
#  'Arvind Nithrakasyap',
#  'Hércules do Prado',
#  'Hyung-Woo Park',
#  'T. E. J. Vos',
#  'Dinei A. Florêncio',
#  'Claude Pegard',
#  'Scott Chiu',
#  'M. Y. Siyal',
#  'Carsten Rücker',
#  'William E. Johnston',
#  'Michael Simpson',
#  'Jörg Schultz',
#  'Thomas Sikora',
#  'Y. N. Lakshman',
#  'M. Choon Chan',
#  'Yiannis Aloimonos',
#  'Rustam Gamzayev',
#  'Niels Da Vitoria Lobo',
#  'Donald P. Eickstedt',
#  'Guillermo Payá',
#  'Alan Small',
#  'Gong Mei',
#  'Hoppe Hugues',
#  'Yoshinari Kanamori',
#  'Carlos Perez',
#  'Chung-Shen Li',
#  'T. A. Nguyen',
#  'Nicolas Perez de la Blanca',
#  'Eric Vitikiotis-Bateson',
#  'Kyung Yong Chwa',
#  'V. Vullo',
#  'Rob F. Van der Wijngaart',
#  'M. S. Balan',
#  'Slarisse Sieckenius de Souza',
#  'Brian A. Malloy',
#  'J. H. Simon Thornton',
#  'Ryan K. L. Ko',
#  'Ron Rice',
#  'Dimitrios Pendarakis',
#  'Vanco B. Litovski',
#  'Jerry Fowler',
#  'Maria das Graças Volpe Nunes',
#  'David H. Pitt',
#  'Laurent Vienot',
#  'Peter Cheung',
#  'Celso M. da Costa Felipe Martins Müller',
#  'Joe D. Martin',
#  'Natalya O. Garanina',
#  'Michael S. Holmes',
#  'Frank Van Eynde',
#  'Antonio Cantoni',
#  'A. J. Al-Khalili',
#  'Dmitrij P. Skvortsov',
#  'J.-R. Abrial',
#  'Kok F. Lai',
#  'G. Iuculano',
#  'Hyeong-Il Kim',
#  'H. Gall',
#  'TingTing Hwang',
#  'P. Kantor',
#  'Lars Karlsson',
#  'Guangyi Chen',
#  'Baolong Liu',
#  'Hanifah Shah',
#  'Xunxian Wang',
#  'M. Nedim Alpdemir',
#  'Yiqiu Han',
#  'Henry Chung',
#  'Adil Bagirov',
#  'Filipe de Sá Mesquita',
#  'T. M. Breuel',
#  'Tien-Yu Li',
#  'Peretz Shoval',
#  'Cui Xiao-Jun',
#  'Mummadi Veerachary',
#  'Carlos Cotta',
#  'Zoltan Toth',
#  'Eric Vatikiotis-Bateson',
#  'James F. Geelen',
#  'Eliezer L. Lozinskii',
#  'A. Bijaoui',
#  'Pankaj Agarwal',
#  'Heinrich Mueller',
#  'Harriet H. Kagiwada',
#  'Keun-Sung Bae',
#  'Mark Bernd Kulaczewski',
#  'M. Roncken',
#  'F. Pianegiani',
#  'Christian Pellegrini',
#  'Richard C. Dubes',
#  'Alexander T. Ihier',
#  'Chang-Yun Li',
#  'D. L. Dill',
#  'Clifford J. Weinstein',
#  'Rem W. Collier',
#  'J. Arenas-García',
#  'Larry F. Hodges',
#  'John Coffey',
#  'Hamidreza R. Kanan',
#  'Lauretta Jones',
#  'Joost Verhofstadt',
#  'Ron J. Byrd',
#  'Thomas Rokicki',
#  'Manuel Tarrio',
#  'A. Ledeczi',
#  'Tuan D. Pham',
#  'C. R. Leedham-Green',
#  'Ben Krose',
#  'Vonkyoung Kim',
#  'Jelassi T',
#  'Jana Koehler',
#  'Nathalie Japckowicz',
#  'Eilon Vaadia',
#  'YingXia Niu',
#  'A. A. Osman',
#  'Michael H. Goldbaum',
#  'José Manuel Torres',
#  'Seongil Jin',
#  'Kyong Chang',
#  'María José Presso',
#  'Richard L. Graham',
#  'Charles Wampler',
#  'Tang Shi Wei',
#  'J.-L. Philippe',
#  'U. Rerrer',
#  'Jian-wei Yin',
#  'Lars Wanhammer',
#  'Jay M. Martin',
#  'S. F. A. Shah',
#  'Antonis Paschalis',
#  'Z. Q. Liu',
#  'P. A. Jensen',
#  'Fred E. Cohen',
#  'Luc Neumann',
#  'Gale L. Martin',
#  'Antonio G. Gómez-Skarmeta',
#  'Changwoo Kang',
#  'Dong-Hoi Kim',
#  'Janka Chlebikova',
#  'Jorge F. Mejías',
#  'Mike Dahlin',
#  'Jérôme Mars',
#  'Yonit Kesten',
#  'Orly Lipshtat',
#  'Stan Z. Li',
#  'Sandra A. Slaughter',
#  'Jirí Matouek',
#  'André Barroso',
#  'A. Perrig',
#  'C. Toinard',
#  'Kamalakar Karlapalem',
#  'Ulrich Neumann',
#  'Michaela Sabin',
#  'Reza Razavi',
#  "Maire P. O'Neill",
#  'Vincenzo Di Martino',
#  'Cuesta E. Cuesta',
#  'Martin K. van Ittersum',
#  'Lori M. Bruce',
#  'John G. Rokne',
#  'Didier Haspeslagh',
#  'D. Davies',
#  'Benoit Champagne',
#  'B. Paechter',
#  'Álvaro Silva',
#  'H. Huber',
#  'Bjorn Poonen',
#  'Setsua Arikawa',
#  'Hans Mühlbacher',
#  'N. Viswanadham',
#  'Inmaculada Garcí',
#  'Mark D. Watson',
#  'Emilio Carrizosa',
#  'Brent Maundy',
#  'S. O. Kuznetsov',
#  'Eberhard O. Voit',
#  'Tessa A. Lau',
#  'Chun-xiao Xing',
#  'Dietmar F. Roesner',
#  'G. Rozenberg',
#  'Weiss',
#  'Wolfgang Strasser',
#  'Svein O. Hallsteinsen',
#  'G. Pour',
#  'Jason Cong',
#  'Emilio L. Zapatam',
#  'B. Zalik',
#  'Noemi de La R. Rodriguez',
#  'Adina Shamir',
#  'Alessandro Donati',
#  'Behazd Sharif',
#  'Seng-cho T. Chou',
#  'T. J. Cook',
#  'A. Caminada',
#  'F. Aguado',
#  'R. Sarker',
#  'A. Jusoh',
#  'José Mira Mira',
#  'Y. Hamada',
#  'Mathieu Rouard',
#  'S. Ramanna',
#  'Cläudio T. Silva',
#  "Daniel Král'",
#  'E. Stella',
#  'Tolga Örs',
#  'Ernesto Compatangelo',
#  'Simon H. Lavington',
#  'Brian Knight',
#  'Ye Tian',
#  'Alexandra Galatescu',
#  'Sun Yongqiang',
#  'Lutz Trahms',
#  'José Manuel Gutierrez',
#  'Géza Nemeth',
#  'J. Cole',
#  'Yu-jin Wu',
#  'Dan Garcia',
#  'Zoran Vukic',
#  'Frederick Truchetet',
#  'Dadiv A. Carrington',
#  'Natalia Juristo Juristo',
#  'Leon O. Chua',
#  'Ming Yu Yao',
#  'Charles S. Newton',
#  'K. G. Arvanitis',
#  'Koichi Takagi',
#  'Pablo López-Matencio',
#  'X. L. Zhang',
#  'Adrián Población-Hernández',
#  'Yan Qiu Chen',
#  'Colin Archibald',
#  'Michael Schroder',
#  'Melek Demirhan',
#  'T. Kaihara',
#  'Takahiro Koita',
#  'W. H. Lau',
#  'H. E. Michail',
#  'Gennady V. Tsarenkov',
#  'Mark J. T. Smith',
#  'Markus Aleksy',
#  'M. Reitzner',
#  'J. W. Essex',
#  'Carsten Griwodz',
#  'Tamas Hauer',
#  'Frank T. Conway',
#  'Evangelos Bekiaris',
#  'Kenneth Sörenson',
#  'Stefano Maranó',
#  'XinWei Wang',
#  'Dirk Bartz Sebastian Ley',
#  'Takuji Kousaka',
#  'Juan Gómez-Luna',
#  'K. J. Kaly',
#  'Frédéric Gagnon',
#  'Vassilios Peristeras',
#  'Kok Kiong Tan',
#  'Dawei Song',
#  'Paul A. Dunn',
#  'Cláudio de Souza Baptista',
#  'Motohisa Funabashi',
#  'D. Marcu',
#  'Silvio Romero de Lemos Meira',
#  'Jan O. Pedersen',
#  'Sunsoo Yoon',
#  'Mafijul Islam',
#  'U. Moon',
#  'Y. Tamura',
#  'William M. Coughran',
#  'W. P. Dayawansa',
#  'Diego Zapata-Rivera',
#  'Graham R. Hellestrand',
#  'Jeremy Heiner',
#  'Sang Soon Park',
#  'B. Krieg',
#  'Vincent Gay-Bellile',
#  'A. Royer',
#  'John Brian Long',
#  'Barbara Buttenfield',
#  'Martina Maggio',
#  'Ralph Cavin III',
#  'Ismael Solis Moreno',
#  'Jan Uhlir',
#  'Gareth Monkman',
#  'Larbi Mesbahi',
#  'Christopher Carothers',
#  'Ken D. Eason',
#  'Ricardo J. G. B. Campello',
#  'Rossa Gaeta',
#  'Edwin K. P. Chong',
#  'Xiolei Qian',
#  'David F. Torchiana',
#  'Jon-Ming Chang',
#  'Yves Louet',
#  'Chin-Chin Liu',
#  'Donald Thomas',
#  'Elieze Levy',
#  'Louis A. Lefebure',
#  'Maria T. López',
#  'M. J. Corbin',
#  'Mariel Vázquez',
#  'A. State',
#  'Tim R. Hopkins',
#  'Nüfer Yasin Ates',
#  'Tak Keung Cheng',
#  'omenico Tegolo',
#  'Frédéric Bouchara',
#  'J. Lagajac',
#  'Stephen K. Wismath',
#  'Koen Danckaert',
#  'Oliver Brand',
#  'Charoensak Charayaphan',
#  'Anirudha S. Gokhale',
#  'Stavros Tsakalidis',
#  'B. Shafai',
#  'Holly J. Trask',
#  'R. Ramesch',
#  'Henrique Joã L. Domingos',
#  'James R. Diebel',
#  'Debra Hensgen',
#  'C. Vazquez',
#  'Jan Genci',
#  'Wi Melody Moh',
#  'Andrea Bianco',
#  'Julio C. Loez',
#  'Bob Askwith',
#  'Michel Desvignes',
#  'Youngsung Shin',
#  'Xing-De Mo',
#  'Murat Azizoglu',
#  'Mary Barton',
#  'James Carswell',
#  'Jeretta Horn Nord',
#  'M. Munro',
#  'Mark B. Sandler',
#  'Kenji Takeda',
#  'Wolfgang Banzhaf',
#  'K. Dresner',
#  'Yann-hang Lee',
#  'E. Mordecki',
#  'Kevin N. Gurney',
#  'Xiaofei Xu',
#  'K. A. Johnson',
#  'Riccardo Rizzo',
#  'João Magalhães',
#  'Sirgrún Andradóttir',
#  'Elias Procópio Duarte Júnior',
#  'Michel Bister',
#  'Ken Leng Siau',
#  'Liu Linzhong',
#  'Franky Leyn',
#  'Sheikh Iqbal Ahamed',
#  'María Angeles Gil',
#  'Ramanathan Sethuraman',
#  'Markku Tukiainen',
#  'Nikolaos Galatsanos',
#  'LJubisa A. Stankovic',
#  'Robert T. H. Chi',
#  'Peter Liden',
#  'João Brisson-Lopes',
#  'Hong-Jun Zhou',
#  'Jeff Paris',
#  'Tobias Freudenreich',
#  'Angeles G. Navarro',
#  'Constantions S. Pattichis',
#  'Gilberto Camara',
#  'J. Cornelis',
#  'Bryan Loyall',
#  'Travis R. Rose',
#  'Gregory G. Slabaugh',
#  'P. S. Kumar',
#  'G. Guzmán',
#  'ShaoBin Cai',
#  'Magali González',
#  'S. Haddad',
#  'Jack R. Zgierski',
#  'Andy P. King',
#  'Laci Mary B. Manhaes',
#  'Joaquim Gabarró',
#  'Hong-Gu Ahn',
#  'Luis Almeida',
#  'Ellen Lowenfeld Walker',
#  'Issam Moghrabi',
#  'Ye-wei Li',
#  'Brent Price',
#  'Ibrahim Kolcu',
#  'Diego Vázquez',
#  'José Carlos Ferreira da Rocha',
#  'M. J. Lipman',
#  'Dabiel Gajski',
#  'Perry A. Emrath',
#  'Kerry A. Raymond',
#  'Hans Mhlbacher',
#  'K. W. Lyons',
#  'Junzo Takahasi',
#  'K-H. Lee',
#  'Don Kiphart',
#  'Joachim Wahlem Michael Schreckenberg',
#  'Ned. C. Rouze',
#  'Marcus Magnor',
#  'Stephen Perelgut',
#  'Hüseyin Kemâl Çakmak',
#  'Wen Ching Wu',
#  'Mark D. Spiteri',
#  'Kris van Marcke',
#  'Sandi Klavzar',
#  'Neal Young',
#  'John W. M. Rogers',
#  'Chung-Yang Huang',
#  'James M. Baker Jr.',
#  'P. Goyal',
#  'Jean Emmanuel Viallet',
#  'Edward C. van der Meulen',
#  'Gordon Kurtenback',
#  'H. Cox',
#  'Michael J. Ackerman',
#  'Roy Eagleson',
#  'Norishige Chiba',
#  'David Albrecht',
#  'Gilles Didier',
#  'Jean-Paul Brassard',
#  'Soon-Yi Wu',
#  'Amy W. Lim',
#  'Miroslaw Bober',
#  'Jinyan Wu',
#  'J. D. Allen',
#  'Paul D. Docherty',
#  'Zinaida Benenson',
#  'S. Su',
#  'Chi-Haur Wu',
#  'Nathalie Laurent',
#  'U. Ernst',
#  'Nirmal Baran Hui',
#  'Wolfgang Koenig',
#  'Aris Anagnostopoulos',
#  'D. J. Parry Smith',
#  'Hiroshi Ishikawa',
#  'Steve Rehfuss',
#  'Angel D. Sappa',
#  'Peter Schröoder',
#  'Helen E. Johnson',
#  'Qingyun Wang',
#  'Jae Moon Kim',
#  'Francesca Cioffi',
#  'Mai K. Nguyen',
#  'Camille B. Achour',
#  'Vittorio Castelli',
#  'Catherine Meadows',
#  'Luay H. Taha',
#  'Kenneth P. Fishkin',
#  'Jon G. Kuhl',
#  'Peter Hassenpflug',
#  'Richard Paige',
#  'Georgios B. Giannikis',
#  'Brian Lings',
#  'Khaled M. Elbassioni',
#  'Brian Barrett',
#  'Eric M. Dashofy',
#  'Ben Van Wyk',
#  'Roseli Aparecida Francelin Romero',
#  'Jim F. Baldwin',
#  'Russell Tessier',
#  'M. Popescu',
#  'Arul D. Murugan',
#  'Hsien-Ming Wul',
#  'Yannis I. Manolessos',
#  'William P. Thurston',
#  'Mo Manning',
#  'Rashid Ansari',
#  'Carolina Miro',
#  'ZuWhan Kim',
#  'Jon Kerridge',
#  'Henry L. Owen',
#  'A. Zafra',
#  'P. Shoval',
#  'Assunta Manniello',
#  'Jean-Louis Dillenseger',
#  'S. Dempe',
#  'Huaxin You',
#  'Bengt Sandblad',
#  'Xiao Zhonge',
#  'A. O. Slissenko',
#  'B. Gunsel',
#  'Martin Arlitt',
#  'Michael Ramscar',
#  'Kenneth Forbus',
#  'Maurizio Molinaro',
#  'C. R. Stephens',
#  'P. De Smet',
#  'Magne Jorgensen',
#  'Patrick Solé',
#  'Pankaj Kumar Agarwal',
#  'Yan Rongguo',
#  'Neil Bergmann',
#  'João Cardoso',
#  'F. D. Brewer',
#  'C. Scoglio',
#  'Miguel Torres',
#  'D. K. Friesen',
#  'Javier Santoyo',
#  'Bhavani M. Thuraisignham',
#  'Joel A. Rosiene',
#  'Ed Kazmierczak',
#  'D. Rees',
#  'William Fisanick',
#  'RobertMDavison',
#  'Lai-Man Po',
#  'Jeffery R. Westbrook',
#  'Chilukuri K. Mohan',
#  'L. Leherte',
#  'Néstor J. Rodríguez',
#  'Zhongfei (Mark) Zhang',
#  'Thorsten Schafer',
#  'Pu Geguang',
#  'Byoung Joon Min',
#  'Robert M. Zimmer',
#  'H. Cruse',
#  'Akihiro Tsutsui',
#  'Jorge J. Gomez-Sanz',
#  'Jose M. Ferrández',
#  'Boris V. Cherkassy',
#  'Ruy de Queiroz',
#  'Tamas Horvath',
#  'Andreas J. Drexler',
#  'T. D. J. Perkins',
#  'Zhang Suqin',
#  'Lambert Spaanenburg',
#  'Sascha Molterer',
#  'Jerry Chou',
#  'Eduardo D. Sontage',
#  'Geoffrey B. Jackson',
#  'James S. Plank',
#  'Peivand Tehrani',
#  'In-Young Kim',
#  'He LiYun',
#  'Hyung-Hyo Lee',
#  'Adrian Santarosa Vivacqua',
#  'R. Hoare',
#  'Krzystof Cetnarowicz',
#  'Qian-Ping Gu',
#  'G. Hernandez',
#  'Jun Xie',
#  'Ewart R. Carson',
#  'Danielle Ziébelin',
#  'M. Clapp',
#  'Robert Bayer',
#  'Stanley Chen',
#  'O. Trelles',
#  'Hansye S. Dulimart',
#  'A. Luk',
#  'Björn Medeke',
#  'Rajiv M. Dewan',
#  'Karam Chatha',
#  'Richard F. Paige',
#  'Li-Zhu Zhou',
#  'S. Yuh',
#  'L. Snidaro',
#  'Reinhold Haeb-Umbach',
#  'Sung Joo Kim',
#  'Martin Griss',
#  'Joong Kyu Kim',
#  'H. C. B. Chan',
#  'Craig D. B. Boyle',
#  'K. Toyama',
#  'A. Grau',
#  'O. Heinz',
#  'Leifur Þ. Leifssona',
#  'Mario J. Pérez-Jiménez',
#  'Chia H. Yeh',
#  'Pedro Bernaola-Galán',
#  'Vipul Goyal',
#  'Miquel A. Senar',
#  'John Clarkson',
#  'Hamid Abrishami Moghaddam',
#  'Peer Kroger',
#  'Kasper Hornbaek',
#  'An Chi Guo',
#  'G. Bier',
#  'Evan D. Lock',
#  'Peter Gorny',
#  'Carlos Murillo-Sénchez',
#  'Sachindra Joshi',
#  'Tang Yue',
#  'C. D. Wezeman',
#  'Manuel Ojeda',
#  'Jim Q. Smith',
#  'Thierry Soussi',
#  'Mario Jarmasz',
#  'Klaus Mueller',
#  'Paolino Di Felice',
#  'Qian Peide',
#  'Frédérik Alexandre',
#  'Erik L. Dagless',
#  'Manish Agarwal',
#  'N. A. Farmer',
#  'John Mylopoulos',
#  'Choon-Bo Sim',
#  'J.-M. Morvan',
#  'Jörg Walter',
#  'Kathrin M. Möslein',
#  'William C. Chu',
#  'A. V. Holden',
#  'Jindon Chen',
#  'E. De Ves',
#  'Chien-Hung Liu',
#  'Stéphane Brez',
#  'Michal Cernansy',
#  'Minyou Wu',
#  'K. Becker',
#  'Juhan P. Ernits',
#  'Félix Hernandez-Campos',
#  'J. Pineda de Gyvez',
#  'Christian J. A. Sigrist',
#  'S. E. Salcudean',
#  'J. L. Aguilar',
#  'Héctor-Gabriel Acosta-Mesa',
#  'John F. Ogilvie',
#  'Stephen Wingreen',
#  'George Wilkie',
#  'Douglas A. Reynolds',
#  'Alvin Bayliss',
#  'Shouichi Hirose',
#  'Ichiro Osawa',
#  'Y. Y. Zeevi',
#  'A. Aydin Alatan',
#  'Jong Eun Ha',
#  'Klaus F. X. Mayer',
#  'D. P. F. Möller',
#  'Maytal Saar Tsechansky',
#  'Andries Petrus Engelbrecht',
#  'S. E. Rees',
#  'Siong Choy Chong',
#  'Murat Kunt',
#  'Jian Xun Peng',
#  'John J. Parry',
#  'Michael Van Ginkel',
#  'Ghulam A. Farruk',
#  'Andres Rudmik',
#  'W. Ertel',
#  'Elizabeth Sueli Specialski',
#  'S. A. Linton',
#  'Chris McMahon',
#  'Satoshi Nakamura',
#  'Martin Kollingbaum',
#  'Gregory F. Pfister',
#  'M. S. A. Suttorp Schulten',
#  'Malini. B. Nayak',
#  'Emanuele Menegatti',
#  'Zeng-zhi Li',
#  'Marcelo Bertalmio',
#  'Peter Bingley',
#  'W. Lauterbach',
#  'Avgoustous A. Tsinakos',
#  'Pedro Gómez-Vilda',
#  'Mark Grant',
#  'Víctor M. Gulias',
#  'M. Sablatash',
#  'Mireille Blay-Fornarino',
#  'Athanassios Skodras',
#  'Ruiming Shen',
#  'Michael B. Hursthouse',
#  'Dana Yoerger',
#  'Jirí Pospisil',
#  'Robert C. Aitken',
#  'William P. Kustas',
#  'David A. Hanauer',
#  'Ian A. Stewart',
#  'Natalino G. Busa',
#  'S. Q. Zheng',
#  'G. Pavlidis',
#  'John Trinder',
#  'P. Coulton',
#  'Sandeep S. Kulkarni',
#  ...}

# %%
# --- Create name pairs from CSV ---
pairs = list(zip(df['# OLD_NAME'], df[' NEW_NAME']))
pairs[:10]
# Out:
# [('Bamshad Mobasherm', 'Bamshad Mobasher'),
#  ('Carole Delporte-Gellet', 'Carole Delporte-Gallet'),
#  ('Ronald Presott Loui', 'Ronald Prescott Loui'),
#  ('Eve Riskin', 'Eve A. Riskin'),
#  ('Doouglas W. Clark', 'Douglas W. Clark'),
#  ('P. R. S. Visser', 'Pepijn R. S. Visser'),
#  ('Pepijn Visser', 'Pepijn R. S. Visser'),
#  ('A. Pietracaprina', 'Andrea Pietracaprina'),
#  ('M. R. Swanson', 'Mark R. Swanson'),
#  ('Matilde Celma-Giménez', 'Matilde Celma')]

# %%
print(f"Total unique mentions: {len(all_names)}")
print(f"Total known pairs: {len(pairs)}")
# Out:
# Total unique mentions: 80279
# Total known pairs: 45156

# %%
# Strategy S1: Extract surname (last part after space)
def extract_surname(name):
    return name.strip().split()[-1]

# Strategy S2: Extract initials (first letter of each word, uppercased)
def extract_initials(name):
    return ''.join(part[0].upper() for part in name.strip().split())

# %%
# Extract surnames from names
surnames = [extract_surname(name) for name in all_names]

# Display a few samples
print("🔹 Sample extracted surnames:")
for surname in list(surnames)[:10]:  # Show only first 10
    print("-", surname)
# Out:
# 🔹 Sample extracted surnames:
# - Dautricourt
# - Degen
# - Guénoche
# - Cho
# - Meitzler
# - Luczak
# - Tichý
# - Chen
# - Mehrez
# - Quintas

# %%
# Extract initials from names
initials = [extract_initials(name) for name in all_names]

# Display a few samples
print("🔹 Sample extracted initials:")
for initial in list(initials)[:10]:  # Show only first 10
    print("-", initial)
# Out:
# 🔹 Sample extracted initials:
# - JD
# - WLFD
# - AG
# - SC
# - TM
# - TL
# - PT
# - XC
# - HM
# - LCQ

# %%
# Build blocks using a chosen strategy function
def build_blocks(names, strategy_func):
    blocks = defaultdict(list)
    for name in names:
        key = strategy_func(name)
        blocks[key].append(name)
    return blocks

# Count pairwise comparisons required within blocks
def count_pairwise_comparisons(blocks):
    return sum(len(block) * (len(block) - 1) // 2 for block in blocks.values())

# Compute recall: how many known pairs fall into same block
def compute_recall(pairs, blocks):
    block_lookup = defaultdict(set)
    for key, block_names in blocks.items():
        for name in block_names:
            block_lookup[name].add(key)

    same_block_count = sum(1 for a, b in pairs if block_lookup[a] & block_lookup[b])
    return same_block_count / len(pairs)

# Compute savings: how many pairwise comparisons are avoided
def compute_saving(num_mentions, blocked_comparisons):
    total_possible = num_mentions * (num_mentions - 1) / 2
    return 1 - (blocked_comparisons / total_possible)

# %%
# Apply Strategy S1
s1_blocks = build_blocks(all_names, extract_surname)
s1_comparisons = count_pairwise_comparisons(s1_blocks)
s1_recall = compute_recall(pairs, s1_blocks)
s1_saving = compute_saving(len(all_names), s1_comparisons)

print(f"🔷 Strategy S1: Surname Blocking")
print(f"Recall: {s1_recall:.4f}")
print(f"Saving: {s1_saving:.4f}")
s1_blocks
# Out:
# 🔷 Strategy S1: Surname Blocking
# Recall: 0.7632
# Saving: 0.9996
# defaultdict(list,
#             {'Dautricourt': ['Jean-Pierre Dautricourt', 'J. P. Dautricourt'],
#              'Degen': ['W. L. F. Degen', 'Wendelin L. F. Degen'],
#              'Guénoche': ['A. Guénoche'],
#              'Cho': ['Sung-Eon Cho',
#               'Soen-Ku Cho',
#               'Ikhwan Cho',
#               'Ho-sik Cho',
#               'Yong-Yun Cho',
#               'Yong Soo Cho',
#               'Jung-Wan Cho',
#               'Hyun-sang Cho',
#               'KwangMoon Cho',
#               'Nam Ik Cho',
#               'Hwan Gue Cho',
#               'Kyoung-Rok Cho',
#               'TaeHo Cho',
#               'W. Cho',
#               'Jun-Ki Cho',
#               'Dong-Ho Cho',
#               'Grun Rae Cho',
#               'Yong-Soo Cho',
#               'Yong J. Cho',
#               'S. H. Cho',
#               'S.-B. Cho',
#               'SeongJe Cho',
#               'Jaeweon Cho',
#               'Wonjoon Cho',
#               'Sung-Bae Cho',
#               'Hyung-Sang Cho',
#               'Seon-ku Cho',
#               'Seon-Ku Cho',
#               'Bongham Cho',
#               'Jong Hyun Park Wan Hyun Cho',
#               'Dae-Soo Cho',
#               'JuHyun Cho',
#               'Seongje Cho',
#               'Jung Wan Cho',
#               'Seong-Hwan Cho',
#               'Daesoo Cho',
#               'Jae Hyun Cho',
#               'Siu-Yeung Cho',
#               'Kyoung Rok Cho',
#               'Seung Ho Cho',
#               'Bonghan Cho',
#               'You-Ze Cho',
#               'Yuk Cho',
#               'Geun Rae Cho',
#               'Yongyun Cho',
#               'Hyung Suck Cho',
#               'You Ze Cho',
#               'Yongjoo Cho',
#               'Young-Joo Cho',
#               'SungEon Cho',
#               'Jaehyun Cho',
#               'Jae Weon Cho',
#               'Yoon Ho Cho',
#               'Wan-Hyun Cho',
#               'Yongsoo Cho',
#               'Hyuk Cho',
#               'Dong Ho Cho',
#               'Yeol J. Cho',
#               'Kyungwoon Cho',
#               'Jungwon Cho',
#               'Yoo-Kun Cho',
#               'Nam-Ik Cho',
#               'Yoon Cho',
#               'SeongHwan Cho',
#               'Jungwan Cho',
#               'Yeol Je Cho',
#               'Hwan-Gue Cho',
#               'Hosik Cho',
#               'Wan Hyun Cho',
#               'Kwang Moon Cho',
#               'Kyongwoon Cho',
#               'Jun-ki Cho',
#               'Hyuntae Cho',
#               'S. Y. Cho',
#               'Ju-Hyun Cho',
#               'Yookun Cho',
#               'Hyungsuck Cho',
#               'SungHo Cho',
#               'Ik-hwan Cho',
#               'Sung Ho Cho',
#               'Sungho Cho',
#               'H. Cho',
#               'Jae-Hyun Cho',
#               'Siu-yeung Cho',
#               'Tae Ho Cho',
#               'Kyoungwoon Cho',
#               'Seungho Cho',
#               'Yong-Joo Cho',
#               'J. W. Cho',
#               'Jung-Won Cho'],
#              'Meitzler': ['Tom Meitzler', 'Thomas Meitzler'],
#              'Luczak': ['Tomasz Luczak',
#               'Malwina J. Luczak',
#               'Tomász Luczak',
#               'M. J. Luczak'],
#              'Tichý': ['Pavel Tichý',
#               'Tomáa Tichý',
#               'Tom Tichý',
#               'Tomás Tichý'],
#              'Chen': ['Xuegang Chen',
#               'Yunmei Chen',
#               'Guangyi Chen',
#               'Yan Qiu Chen',
#               'Stanley Chen',
#               'Jindon Chen',
#               'Chen-Jung Chen',
#               'YunQiang Chen',
#               'Biao Chen',
#               'Mon-Song Chen',
#               'Jonathan H. Chen',
#               'Bo Chen',
#               'Y. Chen',
#               'HuoWang Chen',
#               'G.-D. Chen',
#               'Guihai Chen',
#               'Yenwei Chen',
#               'R. J. Chen',
#               'Yunn-Yen Chen',
#               'Yanqiu Chen',
#               'Bantao Chen',
#               'J.-J. Chen',
#               'Hsi-Chuan Chen',
#               'Bai-Hsuan Chen',
#               'Peter C. Y. Chen',
#               'ChuXin Chen',
#               'Susan Chen',
#               'YanHui Chen',
#               'Yunqiang Chen',
#               'J. X. Chen',
#               'Xilin Chen',
#               'Peter P. Chen',
#               'Xiaotao Chen',
#               'Shui-sen Chen',
#               'Xiaoqi Chen',
#               'P. C. Y. Chen',
#               'Chung-Ming Chen',
#               'Di-Yi Chen',
#               'Enhong Chen',
#               'Tai-Pang Chen',
#               'Chung-Min Chen',
#               'Yu-Yi Chen',
#               'Xiaoping Chen',
#               'Rita Chen',
#               'Z.-M. Chen',
#               'Yu-an Chen',
#               'Jen-Yen Jason Chen',
#               'Yu Zong Chen',
#               'Hengxin Chen',
#               'Yirng-An Chen',
#               'Jason Jen-Yen Chen',
#               'J.-H. Chen',
#               'Phoebe Chen',
#               'Haiming Chen',
#               'Yi-HSiu Chen',
#               'De-Gang Chen',
#               'Shyi-Ming Chen',
#               'Clayton Chi-Chan Chen',
#               'Chao-chen Chen',
#               'Jwu-E. Chen',
#               'Wenjie Chen',
#               'Shyh-Kwei Chen',
#               'Yu G. Chen',
#               'Gen-Huey Chen',
#               'Pozung Chen',
#               'Calvin Ching-Yuen Chen',
#               'Junying Chen',
#               'L.-C. Chen',
#               'Wenliang Chen',
#               'X. J. Chen',
#               'Wen-Sung Chen',
#               'I.-R. Chen',
#               'Haixiong Chen',
#               'Xiaowu Chen',
#               'T.-A. Chen',
#               'Jianyun Chen',
#               'Xiao Tao Chen',
#               'Jindong Chen',
#               'X. P. Chen',
#               'Deqing Chen',
#               'Shu Lei Chen',
#               'Shifu Chen',
#               'Yilong Chen',
#               'Daoxu Chen',
#               'Kuo-Hsiang Chen',
#               'Wentsong Chen',
#               'Y. Q. Chen',
#               'Yi-Ping Phoebe Chen',
#               'Chien-Yu Chen',
#               'Chungmin Melvin Chen',
#               'Dao-xu Chen',
#               'Fu-Chuang Chen',
#               'M.-S. Chen',
#               'Chyouhwa Chen',
#               'Xiang-Rong Chen',
#               'Zhiming Chen',
#               'J. W. Chen',
#               'Hanxiong Chen',
#               'Marina Chen',
#               'Tie Qi Chen',
#               'Lei Shu Chen',
#               'Lih-Yuan Chen',
#               'G Chen',
#               'Charlie Chung-Ping Chen',
#               'Fu C. Chen',
#               'Yan Qui Chen',
#               'Xiuzhen Chen',
#               'Leilei Chen',
#               'Ker-Jiann Chen',
#               'Runsheng Chen',
#               'Yongjian Chen',
#               'Shuo Chen',
#               'Tung-Chieh Chen',
#               'Zhiyuan Chen Chen',
#               'Zhou Chen',
#               'Dong-yuan Chen',
#               'Yun Chen',
#               'Chang W. Chen',
#               'Chao-Chen Chen',
#               'Yan-ping Chen',
#               'DongMei Chen',
#               'I. Ming Chen',
#               'Peng-Yu Chen',
#               'Min Cai Yu Chen',
#               'Li-Yuan Chen',
#               'Jen-Hsiang Chen',
#               'Ta-Kang Chen',
#               'Xilen Chen',
#               'Jake Chen',
#               'Wen-Tsuen Chen',
#               'Sherry Chen',
#               'Siu-Wing Chen',
#               'Yanping Chen',
#               'Xiao-wu Chen',
#               'D Chen',
#               'Calvin C.-Y. Chen',
#               'Jeng-Chung Victor Chen',
#               'Marina C. Chen',
#               'Jun Liang Chen',
#               'Jianer Chen',
#               'Cindy Xinmin Chen',
#               'Danny Z. Chen',
#               'Tian-Ping Chen',
#               'Xiaofeng Chen',
#               'Tsuhun Chen',
#               'Xiu-zhen Chen',
#               'Su-shing Chen',
#               'Kuang-hua Chen',
#               'Weimin Chen',
#               'Zhixiang Chen',
#               'Yuan Chen',
#               'Mei-Juan Chen',
#               'Wu-Hsiang Chen',
#               'Shudong Chen',
#               'Tzung-Her Chen',
#               'Jiujun Chen',
#               'Ying-Ping Chen',
#               'Di-yi Chen',
#               'Rong-si Chen',
#               'Hui Chen',
#               'Jake Yue Chen',
#               'Gen-huey Chen',
#               'Chen',
#               'Yen-Wei Chen',
#               'Hyi-Ming Chen',
#               'XiaoQi Chen',
#               'Yi-long Chen',
#               'A. Chen',
#               'XiaoPing Chen',
#               'Aitao Chen',
#               'Yunn Yen Chen',
#               'Weiping Chen',
#               'Francine R. Chen',
#               'Z. Q. Chen',
#               'Po-zung Chen',
#               'Josette Chen',
#               'Hai-Ming Chen',
#               'Yuehui Chen',
#               'Tai Pang Chen',
#               'De-Sheng Chen',
#               'Xiaoxia Chen',
#               'Xiao-diao Chen',
#               'DeQing Chen',
#               'Weiqi Chen',
#               'Oscal T.-C. Chen',
#               'Shu-Ching Chen',
#               'Jonathan Chen',
#               'Ing-Ray Chen',
#               'Shui-Sen Chen',
#               'Chun-hung Chen',
#               'Chi-Hsien Chen',
#               'Peter C. Chen',
#               'Mike Chen',
#               'Gen-Heuy Chen',
#               'Yung-Fu Chen',
#               'Huaping Chen',
#               'Chun-Hung Chen',
#               'Sherry Y. Chen',
#               'Yangjan Chen',
#               'S. Chen',
#               'Chuxin Chen',
#               'P.-N. Chen',
#               'Yau Qiu Chen',
#               'Hua-mei Chen',
#               'Xiao-Tao Chen',
#               'Charlie C.-P. Chen',
#               'Weidon Chen',
#               'Baoquan Chen',
#               'Tai-Ann Chen',
#               'Qiming Chen',
#               'Ming-Chung Chen',
#               'Kwang-Ting Chen',
#               'haomei Chen',
#               'Zhiaxiang Chen',
#               'Zhaoqian Chen',
#               'Yuun-Yen Chen',
#               'An-long Chen',
#               'Guoliang Chen',
#               'M.-Y. Chen',
#               'Ying-Jui Chen',
#               'Yu. G. Chen',
#               'Kuang-Hua Chen',
#               'Shi-Fu Chen',
#               'Tungshou Chen',
#               'Songcan Chen',
#               'Shu-Hen Chen',
#               'Tsuhan Chen',
#               'Yi-Hsiu Chen',
#               'Yung-fu Chen',
#               'A.-P. Chen',
#               'Han-Fu Chen',
#               'Jiah-Shing Chen',
#               'Zhanglong Chen',
#               'Yirn-An Chen',
#               'Zhao Q. Chen',
#               'Michael K. Chen',
#               'Francine Chen',
#               'Shyk-Kwei Chen',
#               'Bing-Yu Chen',
#               'Chun-Jung Chen',
#               'Chiehfeng Chen',
#               'Michael Chen',
#               'Yumei Chen',
#               'Rongchang Chen',
#               'Yuting Chen',
#               'Hua-Mei Chen',
#               'Charles Zhi-kai Chen',
#               'Yanjun Chen',
#               'Rong-Jaye Chen',
#               'YuZong Chen',
#               'Mou-Yen Chen',
#               'Chun Hung Chen',
#               'W.-T. Chen',
#               'Jiu Jun Chen',
#               'Jen-Yen Chen',
#               'R. M. Chen',
#               'Trista Pei-chun Chen',
#               'Yixin Chen',
#               'Mei-juan Chen',
#               'Ming-yu Chen',
#               'Chun-Te Chen',
#               'Anlong Chen',
#               'Chungmin Chen',
#               'An-Pin Chen',
#               'Rong-Chang Chen',
#               'Rita Yu Chen',
#               'Bai-Hsun Chen',
#               'TieQi Chen',
#               'Li-jia Chen',
#               'Huowang Chen',
#               'X. Josette Chen',
#               'Hsi-Chung Chen',
#               'HanFu Chen',
#               'Stanley F. Chen',
#               'Aito Chen',
#               'Zhao-Qian Chen',
#               'Gwo-Dong Chen',
#               'Weidong Chen',
#               'Yujian Chen',
#               'Dongmei Chen',
#               'Tung-Shou Chen',
#               'Yu Chang Chen',
#               'Po-Ning Chen',
#               'Wei-dong Chen',
#               'Liangfu Chen',
#               'WenSung Chen',
#               'Rung Ching Chen',
#               'Yu-Chang Chen',
#               'Shinin Chen',
#               'Xinkai Chen',
#               'Hongjian Chen',
#               'Keh-jiann Chen',
#               'Patrick S. Chen',
#               'Yangjun Chen',
#               'G. Y. Chen',
#               'Li-Chiou Chen',
#               'Chun-Tee Chen',
#               'Kuohsiang Chen',
#               'Y. B. Chen',
#               'Chieh-Yu Chen',
#               'Chaomei Chen',
#               'Jwu E Chen',
#               'Hsing-Lung Chen',
#               'Haichen Chen',
#               'Bangtao Chen',
#               'W. Chen',
#               'Kuo-Hsing Chen',
#               'Xin-Kai Chen',
#               'Chung-Kuan Chen',
#               'Dan Chen',
#               'Yi-Ping Chen',
#               'Xue-gang Chen',
#               'Jingdong Chen',
#               'Pinhong Chen',
#               'Guoqing Chen',
#               'Jim X. Chen',
#               'Peter Pin-Shan Chen',
#               'Kuo-Sheng Chen',
#               'Rong-Ming Chen',
#               'Baio Chen',
#               'Jiann-Jone Chen',
#               'Ming-Hua Chen',
#               'Yongda Chen',
#               'Tzungher Chen',
#               'Meng Chang Chen',
#               'I-Ming Chen',
#               'Wen-Tsong Chen',
#               'Mingwen Chen',
#               'M.-J. Chen',
#               'Meng-Chang Chen',
#               'O. T.-C. Chen',
#               'Haiguang Chen',
#               'Xiao-Diao Chen',
#               'Chag Wen Chen',
#               'Zhiyuan Chen',
#               'Keh-Jiann Chen',
#               'Shu-Heng Chen',
#               'Ming Chung Chen',
#               'Qianbin Chen',
#               'Qing-Shan Chen',
#               'I.-Ming Chen',
#               'XiaoXia Chen',
#               'Su-Shing Chen',
#               'B-Y Chen',
#               'Ta-Kan Chen',
#               'Huang-Jen Chen',
#               'M. K. Chen',
#               'Jingwen Chen',
#               'Yangquan Chen',
#               'Qian-Bin Chen',
#               'Weiming Chen',
#               'Cindy Chen',
#               'Ying-ping Chen',
#               'Xiangping Chen',
#               'L.-j. Chen',
#               'Irene Chen',
#               'Jiann-Liang Chen',
#               'Jiu-jun Chen',
#               'Ying-jui Chen',
#               'Chyou-Hwa Chen',
#               'Hsieng-Lung Chen',
#               'G. Chen',
#               'Chang Wen Chen',
#               'Degang Chen',
#               'Fa Lai Chen',
#               'Cheng Chen',
#               'Peter P.-S. Chen',
#               'Huan-Jen Chen',
#               'Arbee L. P. Chen',
#               'Rung-Ching Chen',
#               'Dannz Z. Chen',
#               'D. Chen',
#               'Patrick Chen',
#               'Yabing Chen',
#               'J. L. Chen',
#               'Peter Chen',
#               'Irene Y. L. Chen',
#               'Yanhui Chen',
#               'Zen Chen',
#               'Xiangrong Chen',
#               'Ziyi Chen',
#               'Falai Chen',
#               'Junliang Chen',
#               'Wu-Hsiang Jonas Chen',
#               'X. T. Chen',
#               'Minghua Chen',
#               'Yuan Been Chen',
#               'GuoLiang Chen',
#               'Charles Zhi-Kai Chen',
#               'WeiPing Chen',
#               'Huo-Wang Chen',
#               'Heng-Xin Chen',
#               'Youngda Chen',
#               'Ya Bing Chen',
#               'Jeng-Chung (Victor) Chen',
#               'Jian-er Chen',
#               'Wen Jie Chen',
#               'Pengyu Chen',
#               'Guoquing Chen',
#               'Yu-Yii Chen',
#               'JunYing Chen',
#               'Chiehfen Chen',
#               'Dong-Yuan Chen',
#               'Tianping Chen',
#               'Jwu E. Chen',
#               'Xiangdong Chen',
#               'Yi Xin Chen',
#               'Xue-Gang Chen',
#               'Zhang-long Chen',
#               'Clayton Chi-Chang Chen',
#               'Susan S. Chen',
#               'Liang-Fu Chen',
#               'Ning Chen',
#               'Jiah-shing Chen',
#               'Gui-Hai Chen',
#               'Liang-fu Chen',
#               'Yu-Jian Chen',
#               'Wei-qi Chen',
#               'Shimin Chen',
#               'Run-Sheng Chen'],
#              'Mehrez': ['Habib Mehrez',
#               'H. Mehrez',
#               'Abraham Mehrez',
#               'A. Mehrez'],
#              'Quintas': ['Louis C. Quintas',
#               'Joao Quintas',
#               'João Quintas',
#               'Louis V. Quintas'],
#              'Maña-López': ['Manuel J. Maña-López'],
#              'Hesse': ['W. Hesse', 'Wolfgang Hesse'],
#              'Harvey': ['Neal R. Harvey',
#               'S. C. Harvey',
#               'Jackson Harvey',
#               'Stephen C. Harvey',
#               'Jachkson Harvey',
#               'Thimothy J. Harvey',
#               'Timothy J. Harvey',
#               'Neal Harvey',
#               'D. J. Harvey',
#               'Daniel J. Harvey'],
#              'Kim': ['Won-Gyum Kim',
#               'Dong Ku Kim',
#               'Jae-Kyeong Kim',
#               'Shin-Dug Kim',
#               'Hyeong-Il Kim',
#               'Vonkyoung Kim',
#               'Dong-Hoi Kim',
#               'Jae Moon Kim',
#               'ZuWhan Kim',
#               'In-Young Kim',
#               'Sung Joo Kim',
#               'Joong Kyu Kim',
#               'Jung-Jae Kim',
#               'Ki-Tae Kim',
#               'Ii Y. Kim',
#               'Jungguk Kim',
#               'JinYoung Kim',
#               'Tae Eun Kim',
#               'Myoungchurl Kim',
#               'Young H. Kim',
#               'Sangwood Kim',
#               'Chong San Kim',
#               'Sang-Hun Kim',
#               'Heung-Soo Kim',
#               'K. H. (Kane) Kim',
#               'Won-Ha Kim',
#               'Sang-Bae Kim',
#               'Jong-Weon Kim',
#               'Gyeyoung Kim',
#               'Tae-Seon Kim',
#               'Chang Soo Kim',
#               'Hak-Joon Kim',
#               'Hyun Sung Kim',
#               'Heunghwan Kim',
#               'Tae Wan Kim',
#               'Eun-Seok Kim',
#               'Taiyun Kim',
#               'GilChang Kim',
#               'Yu Seop Kim',
#               'Hyun Mun Kim',
#               'Daeyoung Kim',
#               'Jae Bum Kim',
#               'Il Y. Kim',
#               'J.-L. Kim',
#               'Jaesub Kim',
#               'Hak Joon Kim',
#               'Dongsung Kim',
#               'Young Han Kim',
#               'Yung Taek Kim',
#               'Yong Dae Kim',
#               'Young Keun Kim',
#               'Jungjoon Kim',
#               'Sangbae Kim',
#               'Young-Il Kim',
#               'Hyun-Seok Kim',
#               'In Cheol Kim',
#               'Hyun Jin Kim',
#               'Neung-Nam Kim',
#               'Hyung-Shin Kim',
#               'Jung-jae Kim',
#               'Myungchul Kim',
#               'Ho-chan Kim',
#               'Young-Sung Kim',
#               'Tae Hoon Kim',
#               'ByungMoon Kim',
#               'Hyun Seok Kim',
#               'Do-Hyeon Kim',
#               'Myung-soo Kim',
#               'Sangbok Kim',
#               'PanKoo Kim',
#               'Hae Y. Kim',
#               'In Kwon Kim',
#               'Jong Hwa Kim',
#               'Sang-Kyoon Kim',
#               'Hyun Jeong Kim',
#               'Jin H. Kim',
#               'Jong-Bae Kim',
#               'In-Kwon Kim',
#               'Gyoung Bae Kim',
#               'Yuseop Kim',
#               'Minho Kim',
#               'Wook Joong Kim',
#               'Dae-kyo Kim',
#               'Hyong-suk Kim',
#               'Nak-Bin Kim',
#               'Young Kuen Kim',
#               'Young-Kuk Kim',
#               'Jaihie Kim',
#               'In-Cheol Kim',
#               'Jong-Oh Kim',
#               'Jong-Min Kim',
#               'Kyu-Tae Kim',
#               'Hwan Koo Kim',
#               'Young Chul Kim',
#               'Sung-Un Kim',
#               'Byeong Man Kim',
#               'Yongkeol Kim',
#               'Seung Joo Kim',
#               'SunKyung Kim',
#               'Joongkyu Kim',
#               'Hae Yong Kim',
#               'Taejeoung Kim',
#               'Yong Deak Kim',
#               'Byung Cul Kim',
#               'Suhyun Kim',
#               'Ki-Bom Kim',
#               'Sung Deuk Kim',
#               'YoungYong Kim',
#               'Yeon-jun Kim',
#               'Dongsup Kim',
#               'Kiwook Kim',
#               'Seung-Jean Kim',
#               'Heung Hwan Kim',
#               'Nam Sung Kim',
#               'Myoung Ho Kim',
#               'Jin-H. Kim',
#               'Yongguk Kim',
#               'Ki-Wook Kim',
#               'Yoonseong Kim',
#               'Kyung-Ok Kim',
#               'Jung-Hwan Kim',
#               'Jon-Lark Kim',
#               'Jinnyun Kim',
#               'Deok-Soo Kim',
#               'Gerard Jounghyun Kim',
#               'Hyongseop Kim',
#               'Jaewook Kim',
#               'HeeSook Kim',
#               'Boeb Kyun Kim',
#               'Heung-Nam Kim',
#               'Soo H. Kim',
#               'Whee Kuk Kim',
#               'Myung Sup Kim',
#               'WooYoung Kim',
#               'Tai-hoon Kim',
#               'Nam-Sung Kim',
#               'Kyung-jun Kim',
#               'T. W. Kim',
#               'Dae Sun Kim',
#               'Wheekuk Kim',
#               'Keejong Kim',
#               'Jong Weon Kim',
#               'Sang-Bok Kim',
#               'Hye-Chung (Monica) Kim',
#               'Gerard J. Kim',
#               'Hyung C. Kim',
#               'Minsu Kim',
#               'Chang-Hun Kim',
#               'Young Jin Kim',
#               'Chong-Sang Kim',
#               'Seong-Dae Kim',
#               'Jai Hie Kim',
#               'Han-gyoo Kim',
#               'Whee KUK Kim',
#               'Yong-Bin Kim',
#               'Hyeong-il Kim',
#               'YeongSeog Kim',
#               'Jae-Chul Kim',
#               'Dae Woong Kim',
#               'Jeu Young Kim',
#               'Myoung-Sup Kim',
#               'Hyun Chul Kim',
#               'Choelmin Kim',
#               'Sunyong Kim',
#               'Hyoungseop Kim',
#               'Gyu tai Kim',
#               'Yong Soo Kim',
#               'Jingsang Kim',
#               'Hyun-Jeong Kim',
#               'Jin Ho Kim',
#               'Moon-hae Kim',
#               'WheeKuk Kim',
#               'Won Gyum Kim',
#               'Yang Hee Kim',
#               'Jaebum Kim',
#               'Sung-Jae Kim',
#               'Kang-Ho Kim',
#               'Chris Kim',
#               'SunYong Kim',
#               'SangHa Kim',
#               'Yeongjoon Kim',
#               'Tae-Su Kim',
#               'Chul-Woo Kim',
#               'Sung Un Kim',
#               'JaeChul Kim',
#               'Won Yong Kim',
#               'SunJung Kim',
#               'Dong S. Kim',
#               'Keunhyung Kim',
#               'Young Ho Kim',
#               'Tae-hoon Kim',
#               'Hang Joon Kim',
#               'W. Y. Kim',
#               'Wonha Kim',
#               'Dae-Kyoo Kim',
#               'Daejin Kim',
#               'Keecheon Kim',
#               'Chong-Gun Kim',
#               'Hae-Jin Kim',
#               'Sungsoo Kim',
#               'H. K. Kim',
#               'Myung Jun Kim',
#               'Keun-Hyung Kim',
#               'SangHun Kim',
#               'Yoo-shin Kim',
#               'Hyun-Ki Kim',
#               'Seung P. Kim',
#               'Jae Sun Kim',
#               'Doo-Hyun Kim',
#               'Hae-Kwang Kim',
#               'Chang Hun Kim',
#               'Jong-Nam Kim',
#               'HyunSook Kim',
#               'Deok-bong Kim',
#               'Ho-Joon Kim',
#               'JeomGoo Kim',
#               'Jong-Hwa Kim',
#               'Jin-Ho Kim',
#               'Cheolmin Kim',
#               'Jun Ki Kim',
#               'Tae Won Kim',
#               'Ho-Chan Kim',
#               'Wooyoung Kim',
#               'Byunggi Kim',
#               'Sang-Tae Kim',
#               'Hyun Dong Kim',
#               'Kee Choen Kim',
#               'Jung-Hoon Kim',
#               'Yu-Seop Kim',
#               'Hwankoo Kim',
#               'Jin-soo Kim',
#               'Young-Tae Kim',
#               'Chang-Su Kim',
#               'Gilchang Kim',
#               'Myung Chul Kim',
#               'JunKi Kim',
#               'Ho Joon Kim',
#               'Sunkyung Kim',
#               'M. K. Kim',
#               'Jeom Goo Kim',
#               'Sang-Ryong Kim',
#               'Joung-Min Kim',
#               'Chang-hun Kim',
#               'Jin Sung Kim',
#               'Daijin Kim',
#               'Yong-Deak Kim',
#               'Sangwook Kim',
#               'Jason Sungtae Kim',
#               'Hagbae Kim',
#               'Young-kuk Kim',
#               'Deok-Bong Kim',
#               'Jee-Hyub Kim Kim',
#               'Bo H. Kim',
#               'Tae Seon Kim',
#               'Byung-Sang Kim',
#               'Jin S. Kim',
#               'Byungmoon Kim',
#               'Hee Sook Kim',
#               'B. M. Kim',
#               'Kangho Kim',
#               'KiIl Kim',
#               'YoungSung Kim',
#               'Young-Gil Kim',
#               'In Y. Kim',
#               'DooHyun Kim',
#               'Ungmo Kim',
#               'InJung Kim',
#               'Min-Ho Kim',
#               'Yoo Ah Kim',
#               'N.-H. Kim',
#               'Moo Young Kim',
#               'Taejeong Kim',
#               'Jaime Bae Kim',
#               'Hagbal Kim',
#               'Myoung-Ho Kim',
#               'Sanghun Kim',
#               'Whee-kuk Kim',
#               'Do Hyeon Kim',
#               'Jeeyeon Kim',
#               'Jeeyen Kim',
#               'Kee Cheon Kim',
#               'Doungsup Kim',
#               'Hyun-sook Kim',
#               'ByungChul Kim',
#               'Hae Kwang Kim',
#               'Kane Kim',
#               'Myung-Soo Kim',
#               'Kyosun Kim',
#               'Soung Hie Kim',
#               'Jong Bae Kim',
#               'Yong-Dae Kim',
#               'Kibom Kim',
#               'Yong-Jin Kim',
#               'Myoungchul Kim',
#               'Sung-Joo Kim',
#               'Chris H. Kim',
#               'Sehwan Kim',
#               'Soung-Hie Kim',
#               'Byungsang Kim',
#               'Myung J. Kim',
#               'JeongWon Kim',
#               'Jae-Gon Kim',
#               'Hyung Shin Kim',
#               'J. Bae Kim',
#               'Kab Il Kim',
#               'Y.-S. Kim',
#               'Y. H. Kim',
#               'Sung Kim',
#               'Nam-Hee Kim',
#               'Kihwan Kim',
#               'Gil Young Kim',
#               'Bo-Yoen Kim',
#               'Haeng-Kon Kim',
#               'JongNam Kim',
#               'M.-J. Kim',
#               'JaeSub Kim',
#               'Doo Hyun Kim',
#               'Jun-Sung Kim',
#               'Kab I. Kim',
#               'Dong-Ho Kim',
#               'Dae-Sun Kim',
#               'Hagyoung Kim',
#               'Hyun-chul Kim',
#               'Yong-Guk Kim',
#               'Hyun-Chul Kim',
#               'Jihie Kim',
#               'Dong Sung Kim',
#               'Byeon Man Kim',
#               'Kee-Jong Kim',
#               'Gye-Young Kim',
#               'Yoo-Ah Kim',
#               'Chul Woo Kim',
#               'Jung Hoon Kim',
#               'Bo Yeon Kim',
#               'Gyung-Bae Kim',
#               'Yong Sin Kim',
#               'Hag-Young Kim',
#               'Yeon-Jun Kim',
#               'Kyo Sun Kim',
#               'Sang-Ha Kim',
#               'Byung-Gi Kim',
#               'Junho Kim',
#               'Sun-Euy Kim',
#               'Tae-Hoon Kim',
#               'Moo-Young Kim',
#               'Young-il Kim',
#               'Jae-kyoon Kim',
#               'Won Sop Kim',
#               'Keechon Kim',
#               'Eun Seok Kim',
#               'Yoon Seong Kim',
#               'Young-han Kim',
#               'Hag Bae Kim',
#               'Dong-ho Kim',
#               'Heung Soo Kim',
#               'Gil-Young Kim',
#               'Seung Jean Kim',
#               'JaeGon Kim',
#               'Bruce Kim',
#               'Suk Jin Kim',
#               'Chonggun Kim',
#               'SooHyung Kim',
#               'M. C. Kim',
#               'Hyunsook Kim',
#               'Jae kyeong Kim',
#               'Do Hyung Kim',
#               'Gil-Chang Kim',
#               'Haeng-kon Kim',
#               'Do-Hyung Kim',
#               'Dan J. Kim',
#               'Suneuy Kim',
#               'N. B. Kim',
#               'Sukjin Kim',
#               'Pan-Koo Kim',
#               'Wonsop Kim',
#               'Sung-jae Kim',
#               'C.-G. Kim',
#               'Jaesun Kim',
#               'Jason Kim',
#               'Se-Hwan Kim',
#               'Hyun-Dong Kim',
#               'Deok-Hwan Kim',
#               'Young-Keol Kim',
#               'Zu Whan Kim',
#               'S. P. Kim',
#               'Youngtae Kim',
#               'Deok Kim',
#               'Hiecheol Kim',
#               'Hyun-Sung Kim',
#               'Rin-Chul Kim',
#               'Jinsang Kim',
#               'Beob Kyun Kim',
#               'YongSoo Kim',
#               'Kyekyung Kim',
#               'Wongyum Kim',
#               'Soo-Hyung Kim',
#               'JungHwan Kim',
#               'Kab-Il Kim',
#               'Jin-Soo Kim',
#               'J.-D. Kim',
#               'Young-Sik Kim',
#               'Young Gil Kim',
#               'S.-D. Kim',
#               'Jin-Dong Kim',
#               'Hae Jin Kim',
#               'TaiYun Kim',
#               'Kyoung-Ok Kim',
#               'Jung Jae Kim',
#               'Jee-Hyub Kim',
#               'Ki-Tac Kim',
#               'Dongku Kim',
#               'Dong Ki Kim',
#               'Dan Jong Kim',
#               'Youngchul Kim',
#               'Jung-Joon Kim',
#               'Jeuyoung Kim',
#               'Cheeha Kim',
#               'Sang Kyoon Kim',
#               'Ung-Mo Kim',
#               'Y. B. Kim',
#               'Jinsung Kim',
#               'Kyutae Kim',
#               'Hyung Chul Kim',
#               'Dong Hoi Kim',
#               'Hyung Cook Kim',
#               'Gyutai Kim',
#               'Bo Hyoung Kim',
#               'Bruce C. Kim',
#               'Hyoung Seop Kim',
#               'Dong-Soo Kim',
#               'Hang-Joon Kim',
#               'Moon Hae Kim',
#               'Hyunjin Kim',
#               'Jin Hyun Kim',
#               'Yoo Shin Kim',
#               'Jun Sung Kim',
#               'D.-S. Kim',
#               'Jin-nyun Kim',
#               'Ki-Hwan Kim',
#               'Hyun-Cheol Kim',
#               'San-Ryong Kim',
#               'Jin Soo Kim',
#               'K. H. Kane Kim',
#               'Gil Chang Kim',
#               'Won-gyum Kim',
#               'Jae-Kyoon Kim',
#               'Seungjoo Kim',
#               'Chong Sang Kim',
#               'Hie-Cheol Kim',
#               'Myung-Sup Kim',
#               'G. C. Kim',
#               'Jung-Guk Kim',
#               'Young-Jin Kim',
#               'Jae-Wook Kim',
#               'Hyun Mon Kim',
#               'Hyung-Il Kim',
#               'Tai-Hoon Kim',
#               'Dae-gun Kim',
#               'Young Yong Kim',
#               'Kye Kyung Kim',
#               'Sunjung Kim',
#               'Yong-Soo Kim',
#               'Sung D. Kim',
#               'Dae-Woong Kim',
#               'Taihoon Kim',
#               'Jihic Kim',
#               'GyeYoung Kim',
#               'Tae-eun Kim',
#               'Injung Kim',
#               'Hyung-Chul Kim',
#               'Sang-Tea Kim',
#               'Y. T. Kim',
#               'Byung-Chul Kim',
#               'Cheong-Ghil Kim',
#               'Chang-Soo Kim',
#               'Jinsoo Kim',
#               'Hyuncheol Kim',
#               'Tae-Sit Kim',
#               'Hyungill Kim',
#               'Junno Kim',
#               'Dae-Gun Kim',
#               'Jin Young Kim',
#               'Jin-Hyun Kim',
#               'MoonHae Kim',
#               'Han Gyoo Kim',
#               'Pankoo Kim',
#               'Wook-joong Kim',
#               'Jung Hwan Kim',
#               'Sung-Hyuk Kim',
#               'Young-Dae Kim',
#               'Dongki Kim',
#               'YongJin Kim',
#               'Joonoo Kim',
#               'YongSin Kim',
#               'JeongWong Kim',
#               'Hyunchul Kim',
#               'YongSeog Kim',
#               'Von-Kyoung Kim',
#               'Yeong-Joon Kim',
#               'Min-Su Kim',
#               'Myung-Kyun Kim',
#               'Jong-Oh Kim. H. J. Kim',
#               'Hyongsuk Kim',
#               'Ki-Il Kim',
#               'Jaemoon Kim',
#               'Tae-Wan Kim',
#               'Kyungjun Kim',
#               'Jae Kyeong Kim'],
#              'Vemuri': ['Baba Vemuri',
#               'Baba C. Vemuri',
#               'Ranga Vemuri',
#               'B. C. Vemuri',
#               'R. Vemuri'],
#              'McRoy': ['Susan McRoy', 'Susan Weber McRoy'],
#              'Crosby': ['Martha Crosby', 'Martha E. Crosby'],
#              'Vaszil': ['György Vaszil'],
#              'Hope': ['Debra A. Hope',
#               'Beverley G. Hope',
#               'Beverly G. Hope',
#               'Debra Hope'],
#              'Khayat': ['Saied Hosseini Khayat', 'Habib Khayat', 'H. Khayat'],
#              'Alonso': ['Gustovo Alonso',
#               'José M. Alonso',
#               'Gustavo Alonso',
#               'Miguel A. Alonso',
#               'Carlos Alonso',
#               'Pedro Alonso',
#               'C. Alonso',
#               'Maria Emilia Alonso',
#               'L Alonso',
#               'J. M. Alonso',
#               'P. Alonso',
#               'Luis Alonso',
#               'Olga Marroquín Alonso',
#               'Maria Elimia Alonso'],
#              'Bard': ['Jonathan F. Bard'],
#              'Holm': ['Sverre Holm', 'S. Holm', 'Liisa Holm', 'L. Holm'],
#              'Zheng': ['Chong-You Zheng',
#               'Guoliang Zheng',
#               'S. Q. Zheng',
#               'Yuan F. Zheng',
#               'Jing Zheng',
#               'Zhi-Jie Zheng',
#               'Liping Zheng',
#               'Bing Zheng',
#               'Yong-Rui Zheng',
#               'Yu-Jie Zheng',
#               'Wei-Shi Zheng',
#               'Wei Guo Zheng',
#               'Huicheng Zheng',
#               'Lihong Zheng',
#               'Yu-jie Zheng',
#               'Kangfeng Zheng',
#               'Ke Colin Zheng',
#               'Baihua Zheng',
#               'W. Jim. Zheng',
#               'L. R. Zheng',
#               'B. Zheng',
#               'Kougen Zheng',
#               'W. X. Zheng',
#               'Weimin Zheng',
#               'Qi-long Zheng',
#               'R. Zheng',
#               'Ke Zheng',
#               'Hongying Zheng',
#               'Tian Zheng',
#               'Qilong Zheng',
#               'Guo Zheng',
#               'Z. J. Zheng',
#               'Y. F. Zheng',
#               'Weiguo Zheng',
#               'Weiming Zheng',
#               'Li-Rong Zheng',
#               'Wei Xing Zheng',
#               'Zengwei Zheng',
#               'Qi-Lun Zheng',
#               'Weishi Zheng',
#               'Chong-you Zheng',
#               'Leilei Chen Yang Zheng',
#               'Hong-Ying Zheng',
#               'Xizhong Zheng',
#               'W. Jim Zheng',
#               'Rong Zheng',
#               'Baibua Zheng',
#               'Li-ping Zheng',
#               'Huiri Zheng',
#               'Tao Zheng',
#               'Nanning Zheng',
#               'Kou-gen Zheng',
#               'Mei Hong Zheng',
#               'Si-Qing Zheng',
#               'Liang Zheng',
#               'Chuguang Zheng',
#               'Zeng-wei Zheng',
#               'Chu-Guang Zheng',
#               'Chongxun Zheng',
#               'Chong-Xun Zheng',
#               'Yongrui Zheng',
#               'Hiucheng Zheng',
#               'Xi-Zhong Zheng',
#               'Si Qing Zheng',
#               'MeiHong Zheng',
#               'Qi Lun Zheng',
#               'Weimi Zheng',
#               'Huiru Zheng',
#               'Kang-feng Zheng',
#               'WeiShi Zheng'],
#              'Kohlhas': ['Jürg Kohlhas'],
#              'Vazirani': ['Umesh Vazirani',
#               'Umesh V. Vazirani',
#               'Umest Vazirani'],
#              'Gerber': ['Bob Gerber',
#               'Robert H. Gerber',
#               'Christian Gerber',
#               'C. Gerber'],
#              'Sanbani': ['Krishan K. Sanbani'],
#              'Longbo': ['Zhang Longbo'],
#              'Tarantilis': ['Tarantilis D. Tarantilis',
#               'Christos D. Tarantilis'],
#              'Slack': ['Mark G. Slack',
#               'Marc G. Slack',
#               'Jon Slack',
#               'Jon M. Slack',
#               'R. Slack',
#               'Roger Slack'],
#              'Wolff': ['Lawrence B. Wolff',
#               'Lawrence Wolff',
#               'Gregory Wolff',
#               'Stephen S. Wolff',
#               'Gregory J. Wolff',
#               'Ronald W. Wolff',
#               'J. G. Wolff',
#               'J. Gerard Wolff',
#               'R. W. Wolff'],
#              'Balovnev': ['Oleg T. Balovnev', 'Oleg Balovnev'],
#              'Bernardi': ['Paolo Bernardi',
#               'Raffaella Bernardi',
#               'S. Bernardi',
#               'Rafaella Bernardi',
#               'Simona Bernardi',
#               'P. Bernardi'],
#              'Song': ['Siand Wun Song',
#               'D. Song',
#               'Dawei Song',
#               'Ju-won Song',
#               'Enmin Song',
#               'Ju-Won Song',
#               'Ji-Young Song',
#               'Jun-feng Song',
#               'H. J. Song',
#               'MoonBae Song',
#               'B. C. Song',
#               'Hyo Jung Song',
#               'Eunmi Song',
#               'Zhanjiang Song',
#               'Ha Yoon Song',
#               'Xubo Song',
#               'Joo Seok Song',
#               'Eun-Mi Song',
#               'Q. Song',
#               'Hwangjun Song',
#               'Zengmin Song',
#               'D. W. Song',
#               'HwangJun Song',
#               'Han Sae Song',
#               'Wang-cheol Song',
#               'Frank K. H. A. Dehne Siang W. Song',
#               'Jae-bok Song',
#               'E. Song',
#               'Dawn Xiadong Song',
#               'Yuquing Song',
#               'HaYoon Song',
#               'Chang-Geun Song',
#               'Samuel Moon-Ho Song',
#               'Oh-Young Song',
#               'Siang Wun Song',
#               'P. Song',
#               'Yukun Song',
#               'I.-Y. Song',
#               'JooSeok Song',
#               'Samel Moon-Ho Song',
#               'Wang-Cheol Song',
#               'Qingfeng Song',
#               'Hong-Yeop Song',
#               'Qinbao Song',
#               'Yong-Duan Song',
#               'Yongjoo Song',
#               'Han S. Song',
#               'William Wei Song',
#               'Y. Q. Song',
#               'Shi-Jie Song',
#               'Jung Hwan Song',
#               'Yang Song',
#               'Xubo B. Song',
#               'HeeJun Song',
#               'Byung C. Song',
#               'Byung Cheol Song',
#               'Junghwan Song',
#               'William W. Song',
#               'Jae-Bok Song',
#               'Chul Hwan Song',
#               'Guanglei Song',
#               'Xiping Song',
#               'Moon-Bae Song',
#               'Yong Duan Song',
#               'Guang-Lei Song',
#               'Justin Song',
#               'Iickho Song',
#               'Chu-Yi Song',
#               'Oh-young Song',
#               'Jiqiang Song',
#               'Hee-Jun Song',
#               'Dawn Xiaodong Song',
#               'Ji-Qiang Song',
#               'Heng-Jie Song',
#               'Chuyi Song',
#               'Peilin Song',
#               'Dawn Song',
#               'Chull Hwan Song',
#               'Justin J. Song',
#               'Shijie Song',
#               'Yuqing Song',
#               'Jooseok Song',
#               'Jiyoung Song',
#               'Jickho Song',
#               'H. Y. Song',
#               'Wangan Song',
#               'YongJoo Song',
#               'Dawai Song',
#               'Yu-Kun Song',
#               'Yu-Qing Song',
#               'Chang Geun Song',
#               'Hengjie Song',
#               'Ye-Qiong Song',
#               'YeQiong Song',
#               'Xipeng Song',
#               'Il-Yeol Song',
#               'Junfeng Song',
#               'Yeqiong Song'],
#              'Carlini': ['Ugo De Carlini', 'Ugo de Carlini'],
#              'Khan': ['Samee Ullah Khan',
#               'Shoab Khan',
#               'Sohaib Khan',
#               'Huda J. Khan',
#               'I. R. Khan',
#               'A. M. Khan',
#               'Javed I. Khan',
#               'Ishtiaq Rasool Khan',
#               'Md. Zafar Ali Khan',
#               'Shoab Ahmed Khan',
#               'Farrukh Aslam Khan',
#               'Mohammad A.U. Khan',
#               'S. Khan',
#               'Shakil M. Khan',
#               'M. Ali Khan',
#               'Z. Khan',
#               'Javed Khan',
#               'Md. Z. A. Khan',
#               'Zafrulla Khan',
#               'Javad I. Khan',
#               'Shakil Khan',
#               'Asim Yar Khan',
#               'Samee Khan',
#               'Salman A. Khan',
#               'Mohammad A. U. Khan',
#               'Zaheer Abbas Khan',
#               'Zafar Ali Khan',
#               'Farrukh A. Khan',
#               'Huda Khan',
#               'S. A. Khan',
#               'Asif M. Khan',
#               'Muhammad Ali Khan'],
#              'Okamoto': ['E. Okamoto', 'Eiji Okamoto', 'Toshio Okamoto'],
#              'Alshebeili': ['Saleh Alshebeili',
#               'S. A. Alshebeili',
#               'Saleh A. Alshebeili'],
#              'Higgins': ['C. Higgins',
#               'S. A. Higgins',
#               'C. A. Higgins',
#               'Charles M. Higgins',
#               'Desmond G. Higgins',
#               'Colin Higgins',
#               'Des Higgins',
#               'Stewart A. Higgins'],
#              'Babaoglu': ['Ozalp Babaoglu', 'Özalp Babaoglu'],
#              'Jaegar': ['Trent Jaegar'],
#              'Horváth': ['Tamás Horváth',
#               'Sándor Horváth',
#               'S. Horváth',
#               'András Horváth',
#               'Gábor Horváth',
#               'Imre Horváth',
#               'I. Horváth'],
#              'Nehorai': ['Arye Nehorai', 'A. Nehorai', 'Aye Nehorai'],
#              'Albrecht': ['Keno Albrecht',
#               'David Albrecht',
#               'K. Albrecht',
#               'C. Albrecht',
#               'Andreas Albrecht',
#               'A. A. Albrecht',
#               'Christoph Albrecht',
#               'Jeannie Albrecht',
#               'Jeannie R. Albrecht',
#               'Andreas Alexander Albrecht',
#               'David W. Albrecht',
#               'A. Albrecht',
#               'Markus Albrecht',
#               'M. Albrecht'],
#              'Zhang': ['Chunkai Zhang',
#               'Shenwei Zhang',
#               'Mingmin Zhang',
#               'X. L. Zhang',
#               'Zhongfei (Mark) Zhang',
#               'Yalin Zhang',
#               'Heping Zhang',
#               'Jianguo Zhang',
#               'Wenbo Zhang',
#               'Linda Yu Zhang',
#               'Daqing Zhang',
#               'Guanqun Zhang',
#               'Guanglan Zhang',
#               'Xiao-Guang Zhang',
#               'Dongliang Zhang',
#               'Jinfeng Zhang',
#               'Yiying Zhang',
#               'Shi Lei Zhang',
#               'Li-Juan Zhang',
#               'Zhizhou Zhang',
#               'DengYin Zhang',
#               'Byong-Tak Zhang',
#               'Dan Hong Zhang',
#               'Yong-dong Zhang',
#               'Ming Zhang',
#               'Zhi-Lin Zhang',
#               'Liang-Jie Zhang',
#               'HongJiag Zhang',
#               'Zhong Fu Zhang',
#               'Shen-sheng Zhang',
#               'Baoxian Zhang',
#               'Yanchun Zhang',
#               'Nevin Lianwen Zhang',
#               'Da Qing Zhang',
#               'Yongjie Zhang',
#               'Jiawan Zhang',
#               'Jian Zhang',
#               'Da-Qian Zhang',
#               'Hongjian Zhang',
#               'X. D. Zhang',
#               'Shilei Zhang',
#               'Yin Zhang',
#               'Shensheng Zhang',
#               'Chao Zhang',
#               'Shelley XQ. Zhang',
#               'Chang shui Zhang',
#               'L.-Q. Zhang',
#               'Shusheng Zhang',
#               'Qi-Yuan Zhang',
#               'Xiaolin Zhang',
#               'Huaping Zhang',
#               'Naixiao Zhang',
#               'Xiao-Mo Zhang',
#               'ZhenQiu Zhang',
#               'Haixia Zhang',
#               'Hailin Zhang',
#               'Cun-Quan Zhang',
#               'Dongmo Zhang',
#               'Shao-Wu Zhang',
#               'Dong-mo Zhang',
#               'GuangZheng Zhang',
#               'Peng Zhang',
#               'Zhi-lin Zhang',
#               'Jian-Hong Zhang',
#               'Wei Guo Zhang',
#               'S. W. Zhang',
#               'Nevin L. Zhang',
#               'QingHua Zhang',
#               'Honghui Zhang',
#               'Ximin Zhang',
#               'Yongzheng Zhang',
#               'Hong Dan Zhang',
#               'Zhigang Zhang',
#               'Gui-Ling Zhang',
#               'Zhonefei (Mark) Zhang',
#               'Jinhai Zhang',
#               'HongJiang Zhang',
#               'Hongyi Zhang',
#               'Shuwu Zhang',
#               'Chung Zhang',
#               'Lijuan Zhang',
#               'Pen Zhang',
#               'Hongbin Zhang',
#               'Haihong Zhang',
#               'Zhe G. Zhang',
#               'Hong Hui Zhang',
#               'Zhou Zhang',
#               'Chang-shui Zhang',
#               'Ye Zhang',
#               'Shu Yu Zhang',
#               'Xiaolei Zhang',
#               'Shi-Li Zhang',
#               'Changshui Zhang',
#               'Minjiee Zhang',
#               'Xiaohui Zhang',
#               'Ben-Yu Zhang',
#               'Q. J. Zhang',
#               'HongHiang Zhang',
#               'Z.-G. Zhang',
#               'Weiming Zhang',
#               'XiaoQin Zhang',
#               'Guang-Zheng Zhang',
#               'Liang-Jei Zhang',
#               'Tianxu Zhang',
#               'Sanyuan Zhang',
#               'Xiaodong Zhang',
#               'Chang Shui Zhang',
#               'Haizheng Zhang',
#               'Choa Zhang',
#               'Wenyin Zhang',
#               'Jainguo Zhang',
#               'Quan bing Zhang',
#               'Yimin Zhang',
#               'Shifeng Zhang',
#               'Xiaoqin Zhang',
#               'Jian Ying Zhang',
#               'Qi-Jun Zhang',
#               'Benyu Zhang',
#               'Yun Gang Zhang',
#               'Zhe George Zhang',
#               'Hao Lan Zhang',
#               'Guo-yin Zhang',
#               'Haizhong Zhang',
#               'Byoung-Tak Zhang',
#               'Gengdu Zhang',
#               'Yaling Zhang',
#               'Guiling Zhang',
#               'Jian-hong Zhang',
#               'Du Zhang',
#               'YongDong Zhang',
#               'Yong-Dong Zhang',
#               'S. C. Zhang',
#               'Zhenqiu Zhang',
#               'Nanning Zhang',
#               'Xingming Zhang',
#               'Hongjiang Zhang',
#               'Zhao-Qing Zhang',
#               'ShenSheng Zhang',
#               'ShiYong Zhang',
#               'Yong-Zheng Zhang',
#               'Jian-Ping Zhang',
#               'Xin-Li Zhang',
#               'Zhaoqing Zhang',
#               'Huanguo Zhang',
#               'Qianyi. Zhang',
#               'Chenxi Zhang',
#               'Xi Min Zhang',
#               'Yong Jie Zhang',
#               'Shao-hua Zhang',
#               'Minming Zhang',
#               'X.-P. Zhang',
#               'Guo-Min Zhang',
#               'Defu Zhang',
#               'Fuji Zhang',
#               'Jianxin Zhang',
#               'Chunkai K. Zhang',
#               'Chun Zhang',
#               'Weixong Zhang',
#               'YaLin Zhang',
#               'Qinghua Zhang',
#               'H. H. Zhang',
#               'S. Zhang',
#               'Rubo Zhang',
#               'Huan-Guo Zhang',
#               'Guangmei Zhang',
#               'Jiashu Zhang',
#               'Wen-Xiu Zhang',
#               'LiQiang Zhang',
#               'Zhongfie (Mark) Zhang',
#               'Xiaoguang Zhang',
#               'Wei-Guo Zhang',
#               'Guangzhao Zhang',
#               'Yan Zhang',
#               'Jian (Andrew) Zhang',
#               'Lianshen Zhang',
#               'Jian-Pei Zhang',
#               'Shichao Zhang',
#               'Guang Lan Zhang',
#               'Shireng Zhang',
#               'Caiming Zhang',
#               'Yanchuan Zhang',
#               'Ming-Min Zhang',
#               'Quanbing Zhang',
#               'Jianxun Zhang',
#               'H.-J. Zhang',
#               'Yuping Zhang',
#               'Y. Y. Zhang',
#               'Lisa Zhang',
#               'Dengyin Zhang',
#               'Zhuo Zhang',
#               'Xianyu Zhang',
#               'Hong Jiang Zhang',
#               'ZhiZhuo Zhang',
#               'Dafang Zhang',
#               'Shengli Zhang',
#               'Da-Quian Zhang',
#               'Xiao-Lin Zhang',
#               'Xiao-Ping Zhang',
#               'Yongdong Zhang',
# ...
#              'Prabhu': ['Gurpur Prabhu',
#               'Omkamath Prabhu',
#               'Gurpur M. Prabhu',
#               'Girish V. Prabhu',
#               'Girish Prabhu',
#               'G. M. Prabhu',
#               'Omkarnath Prabhu'],
#              'McBride': ['Martin W. McBride',
#               'Richard A. McBride',
#               'Martin McBride',
#               'Richard McBride',
#               'R. A. McBride'],
#              'Shyan-Ming': ['Shyan-Ming'],
#              'Turney': ['Robert D. Turney', 'Robert Turney'],
#              'Dong': ['Qiwen Dong',
#               'Yunmei Dong',
#               'G. Dong',
#               'M. Dong',
#               'Juzhen Dong',
#               'Ligang Dong',
#               'Li-gang Dong',
#               'Sheqin Dong',
#               'ZhaoYang Dong',
#               'Hepu Dong',
#               'Wei-Min Dong',
#               'Jinxing Dong',
#               'Michael J. Dong',
#               'Guangming Dong',
#               'Yi-Sheng Dong',
#               'Yang Dong',
#               'Yisheng Dong',
#               'Xue-Dong Dong',
#               'Zhao Yang Dong',
#               'Jinxiang Dong',
#               'Zhijiong Dong',
#               'Xue-dong Dong',
#               'She-Qin Dong',
#               'Jian-xiong Dong',
#               'Fangyan Dong',
#               'JinXiang Dong',
#               'Yun-Mei Dong',
#               'Qi-wen Dong',
#               'Ju-Zhen Dong',
#               'Guozhu Dong',
#               'Fanyan Dong',
#               'Ping Dong',
#               'G. M. Dong',
#               'Jian-Xiong Dong',
#               'Wei-min Dong',
#               'Zhijiang Dong',
#               'P. Dong',
#               'Jin-xiang Dong'],
#              'Altnçay': ['Hakan Altnçay'],
#              'Trienekens': ['Jos J. M. Trienekens',
#               'Jos Trienekens',
#               'Harry W. J. M. Trienekens',
#               'J. J. M. Trienekens',
#               'Jos J. Trienekens',
#               'H. W. J. M. Trienekens'],
#              'Khakifirooz': ['Ali Khakifirooz', 'A. Khakifirooz'],
#              'Toledo': ['Alberto Lopéz Toledo',
#               'Ricardo Toledo',
#               'F. Toledo',
#               'Ramon Mata Toledo',
#               'Alberto López Toledo',
#               'R. Toledo',
#               'Francisco Toledo',
#               'Olga Bolívar Toledo'],
#              'Sip': ['Henk Sip'],
#              'Tokoro': ['Ken-Ichi Tokoro', 'Ken-ichi Tokoro'],
#              'Shyamasundar': ['R. K. Shyamasundar'],
#              'Yager': ['Ronald R. Yager', 'Susan E. Yager', 'Susan Yager'],
#              'Jianfang': ['Wang Jianfang'],
#              'Degardin': ['V. Degardin', 'Virginie Degardin'],
#              'Bauer': ['Peter H. Bauer',
#               'Josef G. Bauer',
#               'Daniel Bauer',
#               'John Bauer',
#               'Mike Bauer',
#               'K. W. Bauer',
#               'Michael Bauer',
#               'J. G. Bauer',
#               'Jorg Bauer',
#               'Michael A. Bauer',
#               'P. H. Bauer',
#               'Jörg Bauer',
#               'John J. Bauer',
#               'Friedrich L. Bauer',
#               'F. L. Bauer',
#               'Dan Bauer'],
#              'Steinhauser': ['Othmar Steinhauser', 'O. Steinhauser'],
#              'Fernandez': ['J. Cl. Fernandez',
#               'F. Javier Ramirez Fernandez',
#               'J. Fernandez',
#               'Milagros Fernandez',
#               'Lourdes Fernandez',
#               'Marcos Fernandez',
#               'Mary Fernandez',
#               'Eduardo B. Fernandez',
#               'Miguel Angel Fernandez',
#               'M. J. Fernandez',
#               'Inmaculada Garcia Fernandez',
#               'Antonio J. Fernandez',
#               'Francisco V. Fernandez',
#               'Luis Fernandez',
#               'Fernando Fernandez',
#               'F. J. Fernandez',
#               'Jean-Claude Fernandez',
#               'J. C. Fernandez',
#               'Jose-Jesus Fernandez',
#               'Laura Docío Fernandez',
#               'Maribel Fernandez',
#               'Miguel Villar Fernandez',
#               'Aantonio J. Fernandez',
#               'Covadonga Fernandez',
#               'Mary F. Fernandez',
#               'M. Fernandez',
#               'Joaquin Lopez Fernandez',
#               'Francisco Javier Ramirez Fernandez'],
#              'Jo': ['GeunSik Jo',
#               'Geun Sik Jo',
#               'Chang-Hyun Jo',
#               'Chang-Hyan Jo',
#               'Jang-Wu Jo',
#               'Jangwu Jo',
#               'Geun-Sik Jo'],
#              'Plugh': ['William Plugh'],
#              'Hoyer': ['Peter Hoyer', 'Helmut Hoyer', 'H. Hoyer'],
#              'Huot': ['Etienne G. Huot', 'Etienne Huot'],
#              'Swanberg': ['D. Swanberg', 'Deborah Swanberg'],
#              'Fox': ['Dieter Fox',
#               'Nick Fox',
#               'Mark S Fox',
#               'Anthony C. J. Fox',
#               'Geoffrey Fox',
#               'Geoffrey C. Fox',
#               'Jeffreyy A. Fox',
#               'G. C. Fox',
#               'Mark S. Fox',
#               'M. Fox',
#               'D. Fox',
#               'Nick C. Fox',
#               'Anthony J. C. Fox',
#               'Robert M. Fox',
#               'Edward Allan Fox',
#               'Edward A. Fox',
#               'Jeffrey A. Fox',
#               'C. Fox',
#               'Chris Fox'],
#              'Hirvensalo': ['Mika Hirvensalo', 'Vesa Hirvensalo'],
#              'Fischer': ['Gregory S. Fischer',
#               'Volker Fischer',
#               'Lars Fischer',
#               'Michael J. Fischer',
#               'Charles N. Fischer',
#               'Kathleen Fischer',
#               'Thomas R. Fischer',
#               'Michel J. Fischer',
#               'Aanth Fischer',
#               'Matthias Fischer',
#               'Mattias Fischer',
#               'L. Fischer',
#               'Gregory Fischer',
#               'V. Fischer',
#               'T. R. Fischer',
#               'Anath Fischer'],
#              'Yamamoto': ['Shinji Yamamoto',
#               'K. Yamamoto',
#               'Hirosuke Yamamoto',
#               'S. Yamamoto',
#               'Shuichiro Yamamoto',
#               'H. Yamamoto',
#               'O. Yamamoto',
#               'Kazuhiko Yamamoto',
#               'Ou Yamamoto',
#               'Yoshinori Yamamoto',
#               'Shuichiroh Yamamoto'],
#              'Berg': ['Mark J. de Berg',
#               'Bert van den Berg',
#               'Robert Berg',
#               'Alexander Berg',
#               'K. G. van den Berg',
#               'Bert van Den Berg',
#               'Helmut K. Berg',
#               'Ray Berg',
#               'Mark de Berg',
#               'Eric van den Berg',
#               'Jur P. Van Den Berg',
#               'H. Berg',
#               'Alexander C. Berg',
#               'E. van den Berg',
#               'Klaas van den Berg',
#               'Raymond Berg',
#               'Jur P. van den Berg',
#               'Mark T. de Berg',
#               'Robbie Berg'],
#              'Rous': ['William B. Rous'],
#              'Pausch': ['Randy E. Pausch', 'Randy F. Pausch'],
#              'Elia': ['M. Elia', 'Michele Elia'],
#              'Maffeis': ['Olivier Maffeis'],
#              'Jiménez-Fernandez': ['Angel Jiménez-Fernandez',
#               'Ángel Jiménez-Fernandez'],
#              'Fisher': ['Allan L. Fisher',
#               'D. Fisher',
#               'Charles N. Fisher',
#               'Kathleen Fisher',
#               'Marc Fisher',
#               'Robert Burns Fisher',
#               'Allan L Fisher',
#               'Warren W. Fisher',
#               'Michael Fisher',
#               'R. B. Fisher',
#               'Michael J. Fisher',
#               'M. D. Fisher',
#               'Robert B. Fisher',
#               'Douglas Fisher',
#               'Douglas H. Fisher',
#               'Michael D. Fisher'],
#              'Wischy': ['Markus Alexander Wischy', 'Markus Wischy'],
#              'Uyttendaele': ['Matt Uyttendaele', 'Matthew Uyttendaele'],
#              'Pacheco': ['Roberto C. S. Pacheco',
#               'Joaquín Pacheco',
#               'Orrana Pacheco',
#               'Joaquín A. Pacheco',
#               'Marco Aurélio Cavalcanti Pacheco',
#               'Peter S Pacheco',
#               'Antánio Pacheco',
#               'António Pacheco',
#               'Marco Aurélio C. Pacheco',
#               'Oriana Pacheco',
#               'M. Pacheco',
#               'Marco Aurélio Pacheco',
#               'Peter S. Pacheco',
#               'Roberto C. Pacheco'],
#              'Proença': ['Claudia Belmiro Proença',
#               'João Proença',
#               'Hugo Proença',
#               'Alberto José Proença'],
#              'McMullen': ['D. F. McMullen', 'Donald F. McMullen'],
#              'Per-Åke-Larson': ['Per-Åke-Larson'],
#              'Pastrana': ['Jose Luis Pastrana', 'J. L. Pastrana'],
#              'Rasheed': ['Khaled Rasheed', 'K. Rasheed'],
#              'Anglada': ['Marc Vigo Anglada', 'Francisco José Morant Anglada'],
#              'Milosavljevic': ['Gordana Milosavljevic', 'Maria Milosavljevic'],
#              'Wassell': ['Ian J. Wassell', 'Ian Wassell', 'I. J. Wassell'],
#              'Faria': ['Luerbio Faria',
#               'João Pascoal Faria',
#               'Joao Pascoal Faria',
#               'Lilian N. de Faria',
#               'Lilian N. Faria',
#               'L. Faria'],
#              'Hatala': ['Marek Hatala'],
#              'Harget': ['Alan Harget', 'Alan J. Harget', 'A. J. Harget'],
#              'Teisseire': ['Malika Teisseire',
#               'Maguelone Teisseire',
#               'Maguelonne Teisseire'],
#              'Encarnacao': ['José Encarnacao', 'José L. Encarnacao'],
#              'Calkin': ['Neil J. Calkin', 'Neil Calkin'],
#              'Stoyan': ['D. Stoyan',
#               'Herbert Stoyan',
#               'Dietrich Stoyan',
#               'Herber Stoyan',
#               'H. Stoyan'],
#              'Kowalski': ['B. R. Kowalski',
#               'Thaddeus J. Kowalski',
#               'Darius R. Kowalski',
#               'T. J. Kowalski',
#               'Dariusz R. Kowalski',
#               'Robert A. Kowalski',
#               'Robert Kowalski',
#               'Bruce R. Kowalski'],
#              'Tomczyk': ['Arkadiusz Tomczyk', 'A. Tomczyk'],
#              'Oakes': ['Michael P. Oakes', 'Michael Oakes'],
#              'Katzela': ['I. Katzela', 'Irene Katzela'],
#              'Venneri': ['B. Venneri', 'Betti Venneri'],
#              'Brown': ['Carolyn Brown',
#               'Kevin Brown',
#               'Pat Brown',
#               'David C. Brown',
#               'S. D. Brown',
#               'Chirstopher M. Brown',
#               'Timothy X. Brown',
#               'Patrick O. Brown',
#               'Aaron B. Brown',
#               'Timthoy X. Brown',
#               'Richard Brown',
#               'Maxine Brown',
#               'Donna J. Brown',
#               'Kevin Q. Brown',
#               'Alan W. Brown',
#               'Maxime Brown',
#               'L. E. Brown',
#               'Stephen Dean Brown',
#               'A. W. Brown',
#               'T. J. N. Brown',
#               'David G. Brown',
#               'S. Brown',
#               'Paul Walton Purdom Jr. Cynthia A. Brown',
#               'Maxine D. Brown',
#               'Daniel G. Brown',
#               'Robert G. Brown',
#               'R. B. Brown',
#               'Kenneth N. Brown',
#               'Richard B. Brown',
#               'Randy Brown',
#               'Stephen D. Brown',
#               'D. C. Brown',
#               'Daniel Brown',
#               'Carlyn Brown',
#               'D. G. Brown',
#               'D. F. Brown',
#               'T. John Brown',
#               'A. L. Brown',
#               'Aaron Brown',
#               'Alfred L. Brown',
#               'Deryck F. Brown',
#               'Christopher M. Brown',
#               'Kenneth Brown',
#               'Laura E. Brown',
#               'R. Brown',
#               'J. Brown',
#               'T. J. Brown',
#               'Donna Brown'],
#              'Verri': ['M. Cecilia Verri',
#               'Alessandro Verri',
#               'M. C. Verri',
#               'A. Verri'],
#              'Schneider': ['I. Schneider',
#               'Moti Schneider',
#               'Michael Schneider',
#               'Dave Schneider',
#               'Marie-Luise Schneider',
#               'Jeff G. Schneider',
#               'R Schneider',
#               'Chsristian. Schneider',
#               'Christian Schneider',
#               'T. D. Schneider',
#               'S. A. Schneider',
#               'Roland S. Schneider',
#               'Jeff Schneider',
#               'R. S. Schneider',
#               'M. Cristina Schneider',
#               'David Schneider',
#               'Markus Schneider',
#               'Isabelle Schneider',
#               'M. Christina Schneider',
#               'Steve A. Schneider',
#               'Thomas D. Schneider',
#               'Marie-Louise Schneider',
#               'Stan Schneider',
#               'R. Schneider',
#               'Stanley A. Schneider',
#               'Michel Schneider',
#               'Stan A. Schneider'],
#              'González-Tablas': ['Ama I. González-Tablas',
#               'Ana I. González-Tablas'],
#              'Favaro': ['John Favaro', 'J. M. Favaro', 'John M. Favaro'],
#              'McDonagh': ['D. McDonagh', 'Declan McDonagh'],
#              'Perumalla': ['K. Perumalla',
#               'Kaylan S. Perumalla',
#               'Kalyan Perumalla',
#               'Kalyan S. Perumalla'],
#              'Rountev': ['Atanas Rountev'],
#              'Calazans': ['Ney Laert Vilar Calazans',
#               'Ney L. V. Calazans',
#               'Ney Calazans'],
#              'Marcotegui': ['Béatrice Marcotegui', 'Beatriz Marcotegui'],
#              'Loviscach': ['Jörn Loviscach'],
#              'Suresh': ['K. Suresh',
#               'J. Suresh',
#               'Jayaraman Suresh',
#               'Krishnan Suresh'],
#              'Michael': ['C. C. Michael',
#               'Holger Michael',
#               'Ng K. Michael',
#               'Bret Michael',
#               'Maria K. Michael',
#               'J. Bret Michael',
#               'B. Michael',
#               'James Bret Michael',
#               'Maria Michael',
#               'Maged M. Michael',
#               'Christoph Michael',
#               'Rodolphe Michael',
#               'H. Michael',
#               'Christoph C. Michael',
#               'Maged Michael'],
#              'Shi': ['Y. Q. Shi',
#               'Yanjun Shi',
#               'Jiaoying Shi',
#               'Baisheng Shi',
#               'BaiLe Shi',
#               'Meilin Shi',
#               'YouQun Shi',
#               'D. Shi',
#               'Bai-Le Shi',
#               'Wenzhong (John) Shi',
#               'MeiLin Shi',
#               'Hui Shi',
#               'Penfei Shi',
#               'Hiu Shi',
#               'Jiaoyin Shi',
#               'Bai-Sheng Shi',
#               'Daming Shi',
#               'DongCai Shi',
#               'Baile Shi',
#               'Shepherd S.B. Shi',
#               'Dongcai Shi',
#               'Dianxi Shi',
#               'J. Y. Shi',
#               'Peng-fei Shi',
#               'Weiwu Hu Gang Shi',
#               'Shu-Ming Shi',
#               'Wengang Shi',
#               'Qing-yun Shi',
#               'Chunyi Shi',
#               'Bertram E. Shi',
#               'Dian-xi Shi',
#               'P. Shi',
#               'Yan Shi',
#               'Weiping Shi',
#               'Qing-Yun Shi',
#               'Yun Q. Shi',
#               'Shuming Shi',
#               'Youqun Shi',
#               'Rui Shi',
#               'Bertram Emil Shi',
#               'XiaoAn Shi',
#               'Baochang Shi',
#               'Ping Shi',
#               'Yuli Shi',
#               'Yun Q Shi',
#               'Shepherd S. B. Shi',
#               'John Wenzhong Shi',
#               'Bingxin Shi',
#               'Yi Shi',
#               'Shu Ming Shi',
#               'Wenkang Shi',
#               'Yan-jun Shi',
#               'Kuei-Ping Shi',
#               'Bao-Chang Shi',
#               'Che-Hua Shi',
#               'Pengfei Shi',
#               'Yu-Li Shi'],
#              'Komzák': ['Jirí Komzák'],
#              'El-Nahas': ['Amas El-Nahas', 'M. Y. El-Nahas', 'Amal El-Nahas'],
#              'Frías-Martinez': ['Enrique Frías-Martinez'],
#              ...})

# %%
# Apply Strategy S2
s2_blocks = build_blocks(all_names, extract_initials)
s2_comparisons = count_pairwise_comparisons(s2_blocks)
s2_recall = compute_recall(pairs, s2_blocks)
s2_saving = compute_saving(len(all_names), s2_comparisons)

print(f"🔷 Strategy S2: Initials Blocking")
print(f"Recall: {s2_recall:.4f}")
print(f"Saving: {s2_saving:.4f}")
# Out:
# 🔷 Strategy S2: Initials Blocking
# Recall: 0.6529
# Saving: 0.9988
